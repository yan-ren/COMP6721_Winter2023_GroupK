# %% [markdown]
# <a href="https://colab.research.google.com/github/yan-ren/COMP6721_Winter2023_GroupK/blob/main/VGG11/COMP6721_VGG11_Dataset10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ### **Unzip Dataset**

# %%
# !unzip dataset-10N.zip

# %% [markdown]
# ### **Installing Libraries**

# %%
# !pip install thop

# %% [markdown]
# ### **Import Libraries**

# %%
from math import ceil
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils, datasets
import os

import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.utils.data as td
import torch.nn as nn
import torch.nn.functional as F
from matplotlib import image
from matplotlib import pyplot
from collections import defaultdict

import numpy as np
from scipy.signal import savgol_filter
import time
from torchvision import models
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay,classification_report
from PIL import Image
import numpy as np
from sklearn.manifold import TSNE
import pickle
from thop import profile


import json
from PIL import Image as PilImage

# %% [markdown]
# ### **Set GPU & define labels of dataset**

# %%
# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
labels_map = {
      0: "Baked Potato",
      1: "Burger",
      2: "Crispy Chicken",
      3: "Donut",
      4: "Fries",
      5: "Hot Dog",
      6: "Pizza",
      7: "Sandwich",
      8: "Taco",
      9: "Taquito",
}
print(len(labels_map))
# Out:
# 10

# %% [markdown]
# ### **Print device used**

# %%
print(device)
# Out:
# cuda

# %% [markdown]
# ### **Display Dataset Images**

# %%
def displayImages(t_dataset,imageFlag):
    figure = plt.figure(figsize=(8, 8))
    cols, rows = 3, 3
    if imageFlag==0:
      figure.suptitle("Images before preprocessing")
    else:
     figure.suptitle("Images after preprocessing")   
    for i in range(1, cols * rows + 1):
      sample_idx = torch.randint(len(t_dataset), size=(1,)).item()
      img, label = t_dataset[sample_idx]
      img=np.array(img).transpose((1,2,0))
      figure.add_subplot(rows, cols, i)
      plt.title(labels_map[label])
      plt.axis("off")
      plt.imshow(img.squeeze())
    print("\n\n\n################################################\n\n\n")
    plt.show()

# %% [markdown]
# ### **Load Data**

# %%
def data_loader(data_dir_input,batch_sizeGiven,input_size,flag=0,test_split=0.1,val_split=0.1):
# Define dataset directory and transforms
  data_dir = data_dir_input #
  
  data_transform = transforms.Compose([
    transforms.Resize(input_size),
    transforms.RandomRotation(20),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(0.1,0.1,0.1),
    transforms.ToTensor(),
    transforms.Normalize([0.554, 0.450, 0.343],[0.231, 0.241, 0.241]),
    transforms.RandomErasing()
  ])


  if flag==1:
    test_temp_dataset = datasets.ImageFolder(data_dir,transform=transforms.Compose([
    transforms.Resize(input_size),
    transforms.ToTensor(),   
  ]))
    displayImages(test_temp_dataset,0)
    test_temp_dataset = datasets.ImageFolder(data_dir,transform=data_transform)
    displayImages(test_temp_dataset,1)

    data = datasets.ImageFolder(root=data_dir, transform=data_transform)
    # Define train, validation, and test dataset
    dataset_size = len(data)
    test_size = int(test_split * dataset_size)
    val_size = int(val_split * dataset_size)
    train_size = dataset_size - (test_size + val_size)
    train_dataset, test_dataset, val_dataset = td.random_split(data,[train_size, test_size, val_size])  
    print("Train Datset Size After Split",len(train_dataset))
    print("Test Datset Size After Split",len(test_dataset))
    print("Validation Datset Size After Split",len(val_dataset))


    # Create a dictionary to store the number of images per class
    num_images_per_class = defaultdict(int)

    # Iterate over the training dataset and count the number of images in each class
    for image, label in train_dataset:
        num_images_per_class[label] += 1

    # Print the number of images per class
    for label, num_images in num_images_per_class.items():
        print(f"Class {label}: {num_images} images")
  

    # Define the number of classes and generate a list of colors
    num_classes = len(num_images_per_class)
    colors = plt.cm.Set1(np.linspace(0, 1, num_classes))

    # Plot the number of images per class as a bar plot
    #plt.bar(num_images_per_class.keys(), num_images_per_class.values(), color=colors)
    plt.pie(num_images_per_class.values(), labels=num_images_per_class.keys(), colors=colors, autopct='%1.1f%%')
    # Add axis labels and title
    plt.xlabel("Class")
    plt.ylabel("Number of images")
    plt.title("Number of images per class in the training dataset")

    # Create a legend
    labels = [f"Class {label}" for label in num_images_per_class.keys()]
    plt.legend([plt.bar(0, 0, color=colors[i])[0] for i in range(len(num_images_per_class))], labels)
    plt.rcParams["figure.figsize"] = (15,15)
    # Show the plot
    plt.show()
    
    return  

  data = datasets.ImageFolder(root=data_dir, transform=data_transform)
  # Define train, validation, and test dataset
  dataset_size = len(data)
  test_size = int(test_split * dataset_size)
  val_size = int(val_split * dataset_size)
  train_size = dataset_size - (test_size + val_size)
  train_dataset, test_dataset, val_dataset = td.random_split(data,[train_size, test_size, val_size])  
 
  train_loader = DataLoader(train_dataset, batch_size=batch_sizeGiven, shuffle=True, drop_last=False, num_workers=0,pin_memory=True)
  test_loader = DataLoader(test_dataset, batch_size=batch_sizeGiven, shuffle=True, drop_last=False, num_workers=0,pin_memory=True) #shuffle 
  val_loader = DataLoader(val_dataset, batch_size=batch_sizeGiven, shuffle=True, drop_last=False, num_workers=0,pin_memory=True) # shuffle working


  return train_loader,test_loader,val_loader

# %% [markdown]
# ### **Dataset images before and after Preprocessing**

# %%
path="/content/dataset-10N"
saveFilePath="/content/hyperparameters.pkl"
saveModelPath="/content/"
batch_size=32
inputDimension=(256,256)
data_loader(path,batch_size,inputDimension,flag=1)
# Out:
# ################################################
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ################################################
# Train Datset Size After Split 16000
# Test Datset Size After Split 2000
# Validation Datset Size After Split 2000
# Class 0: 1576 images
# Class 9: 1596 images
# Class 6: 1629 images
# Class 5: 1582 images
# Class 2: 1592 images
# Class 4: 1617 images
# Class 8: 1624 images
# Class 3: 1579 images
# Class 1: 1604 images
# Class 7: 1601 images

# %% [markdown]
# ### **Training Loop**

# %%
def train(num_epochsGiven, model, train_loader, criterion, optimizer,val_loader):
  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  print("Device: {}".format(device))
  model.to(device)
  Accuracy=[]
  validAccuracy=[]
  stepAccuracyTotal=[]
  stepAccuracyValidationTotal=[]
  stepLossTotal=[]
  Loss = []
  num_epochs = num_epochsGiven
  total_steps = len(train_loader)
  t1 = time.time()
  total,correct,loss=0,0,0
  for epoch in range(num_epochs):
      stepAcc=[]
      stepLoss=[]    
      for i, data in enumerate(train_loader):
          images, labels = data[0].to(device), data[1].to(device)
          # Forward pass
          outputs = model(images)
          loss = criterion(outputs, labels)
          # Backprop and optimisation
          optimizer.zero_grad()
          loss.backward()
          optimizer.step()
          # Train accuracy
          total = labels.size(0)
          _,predicted = torch.max(outputs.data, 1)
          correct = (predicted == labels).sum().item()
          stepAcc.append((correct / total) * 100)
          stepLoss.append(loss.item())
          if (i + 1) % 30 == 0:
              stepAccuracyTotal.append((correct / total) * 100)
              stepLossTotal.append(loss.item())
              correct_v = 0
              total_v = 0
              for dataVal in val_loader:
                  images_v, labels_v = dataVal[0].to(device), dataVal[1].to(device)
                  outputs = model(images_v)
                  _, predicted = torch.max(outputs.data, 1)
                  correct_v += (predicted == labels_v).sum().item()
                  total_v += labels_v.size(0) 
              stepAccuracyValidationTotal.append((correct_v / total_v) * 100)
              print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%,Validation Accuracy: {:.2f}%'.format(epoch + 1, num_epochs, i + 1, total_steps, loss.item(),(correct / total) * 100,(correct_v / total_v) * 100))     
      correct_v = 0
      total_v = 0
      for dataVal in val_loader:
          images_v, labels_v = dataVal[0].to(device), dataVal[1].to(device)
          outputs = model(images_v)
          _, predicted = torch.max(outputs.data, 1)
          correct_v += (predicted == labels_v).sum().item()
          total_v += labels_v.size(0)        
      Accuracy.append(sum(stepAcc)/len(stepAcc))
      validAccuracy.append((correct_v / total_v) * 100)
      Loss.append(sum(stepLoss)/len(stepLoss))
  endTime =  time.time()
  print("######## Training Finished in {} seconds ###########".format(endTime-t1))
  print("######## Training timer per epoch is {} seconds ###########".format((endTime-t1)/num_epochsGiven))
  return Loss,Accuracy,model,validAccuracy,stepAccuracyTotal,stepAccuracyValidationTotal,stepLossTotal

# %% [markdown]
# ### **Testing**

# %%
def test(model, device, test_loader):
  model.eval() 
  y_truth=[]
  y_predicted=[]
  cm=[]
  G_correct=0
  G_total=0
  
  with torch.no_grad(): 
      correct = 0
      total = 0
      for data in test_loader:
          images, labels = data[0].to(device), data[1].to(device)
          outputs = model(images)
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()
          y_truth+=labels.cpu().numpy().tolist()
          y_predicted+=predicted.cpu().numpy().tolist()
      print('Test Accuracy of the model on the {} test images: {} %'.format(total, (correct / total) * 100))
      cm= confusion_matrix(y_truth,y_predicted)
      G_total=total
      G_correct=correct
  print(classification_report(y_truth,y_predicted))
  return cm,((G_correct / G_total) * 100)

# %% [markdown]
# ### **Hyperparameter Tuning**

# %%
MODELS=[]
hyper_parameters = []
train_acc_hyper_paramaters=[]
train_acc_valid_hyper_paramaters=[]
train_loss_hyper_paramaters=[]

train_acc_hyper_paramaters_step=[]
train_acc_valid_hyper_paramaters_step=[]
train_loss_hyper_paramaters_step=[]
test_loss=[]

#different batch sizes
batch_sizes=[32]
#different learning rates
learning_rates=[0.0001,0.0005,0.001,0.01]
#Setting the number of epochs
epochs=15


for learning_rate in learning_rates:
   for batch_size in batch_sizes:
      #Model VGG11   
      model3 = models.vgg11(weights=None)
      model3.classifier[6] = nn.Linear(4096,len(labels_map))
      stringCrit="Cross Entropy Loss"
      criterion=nn.CrossEntropyLoss()
      #Optimizer Function 
      stringOPTM="Adam Optimizer"
      optimizer = torch.optim.Adam(model3.parameters(), lr=learning_rate)

      hyper_parameters.append(["Learning Rate: "+str(learning_rate)," Batch Size: "+str(batch_size),stringCrit,stringOPTM])
      print("Learning Rate: "+str(learning_rate)+", Batch Size: "+str(batch_size),", Loss function: ",stringCrit,", Optimizer: ",stringOPTM)
      
      train_loader, test_loader, val_loader = data_loader(path,batch_size, inputDimension)
      tempLoss,tempAccuracy,tempModel,tempValidAccuracy,tempStepAccuracy,tempStepValidation,tempStepLoss = train(epochs,model3,train_loader,criterion,optimizer,val_loader)

      
      train_loss_hyper_paramaters.append(tempLoss)
      train_acc_hyper_paramaters.append(tempAccuracy)
      train_acc_valid_hyper_paramaters.append(tempValidAccuracy)

      train_acc_valid_hyper_paramaters_step.append(tempStepValidation)      
      train_acc_hyper_paramaters_step.append(tempStepAccuracy)
      train_loss_hyper_paramaters_step.append(tempStepLoss)

      cmReturned,temp_test_loss = test(model3,"cuda",test_loader)
      test_loss.append([temp_test_loss,learning_rate])
      if cmReturned is not None:
          fig, ax = plt.subplots(figsize=(7, 7))
          ConfusionMatrixDisplay(cmReturned).plot(ax=ax,cmap='Blues', xticks_rotation='vertical', values_format='d')
          plt.show()   
      MODELS.append(tempModel)
# Out:
# Learning Rate: 0.0001, Batch Size: 32 , Loss function:  Cross Entropy Loss , Optimizer:  Adam Optimizer
# Device: cuda
# Epoch [1/15], Step [30/500], Loss: 2.2995, Accuracy: 9.38%,Validation Accuracy: 9.95%
# Epoch [1/15], Step [60/500], Loss: 2.1246, Accuracy: 21.88%,Validation Accuracy: 18.15%
# Epoch [1/15], Step [90/500], Loss: 2.2780, Accuracy: 18.75%,Validation Accuracy: 14.95%
# Epoch [1/15], Step [120/500], Loss: 2.2965, Accuracy: 9.38%,Validation Accuracy: 17.05%
# Epoch [1/15], Step [150/500], Loss: 2.1420, Accuracy: 37.50%,Validation Accuracy: 20.30%
# Epoch [1/15], Step [180/500], Loss: 2.1752, Accuracy: 21.88%,Validation Accuracy: 20.15%
# Epoch [1/15], Step [210/500], Loss: 2.0742, Accuracy: 18.75%,Validation Accuracy: 18.15%
# Epoch [1/15], Step [240/500], Loss: 2.2765, Accuracy: 15.62%,Validation Accuracy: 19.75%
# Epoch [1/15], Step [270/500], Loss: 2.1573, Accuracy: 21.88%,Validation Accuracy: 18.70%
# Epoch [1/15], Step [300/500], Loss: 2.0463, Accuracy: 12.50%,Validation Accuracy: 19.95%
# Epoch [1/15], Step [330/500], Loss: 2.1110, Accuracy: 18.75%,Validation Accuracy: 20.15%
# Epoch [1/15], Step [360/500], Loss: 2.1229, Accuracy: 15.62%,Validation Accuracy: 20.85%
# Epoch [1/15], Step [390/500], Loss: 1.9486, Accuracy: 25.00%,Validation Accuracy: 24.70%
# Epoch [1/15], Step [420/500], Loss: 2.2103, Accuracy: 25.00%,Validation Accuracy: 23.90%
# Epoch [1/15], Step [450/500], Loss: 1.9405, Accuracy: 37.50%,Validation Accuracy: 23.45%
# Epoch [1/15], Step [480/500], Loss: 2.1595, Accuracy: 31.25%,Validation Accuracy: 27.25%
# Epoch [2/15], Step [30/500], Loss: 2.0161, Accuracy: 28.12%,Validation Accuracy: 29.50%
# Epoch [2/15], Step [60/500], Loss: 1.9921, Accuracy: 18.75%,Validation Accuracy: 29.45%
# Epoch [2/15], Step [90/500], Loss: 1.5999, Accuracy: 46.88%,Validation Accuracy: 29.05%
# Epoch [2/15], Step [120/500], Loss: 2.2896, Accuracy: 12.50%,Validation Accuracy: 27.15%
# Epoch [2/15], Step [150/500], Loss: 1.6998, Accuracy: 43.75%,Validation Accuracy: 31.35%
# Epoch [2/15], Step [180/500], Loss: 1.8743, Accuracy: 40.62%,Validation Accuracy: 33.30%
# Epoch [2/15], Step [210/500], Loss: 2.1171, Accuracy: 15.62%,Validation Accuracy: 33.85%
# Epoch [2/15], Step [240/500], Loss: 1.8697, Accuracy: 28.12%,Validation Accuracy: 33.50%
# Epoch [2/15], Step [270/500], Loss: 1.9579, Accuracy: 25.00%,Validation Accuracy: 33.90%
# Epoch [2/15], Step [300/500], Loss: 1.6970, Accuracy: 43.75%,Validation Accuracy: 34.70%
# Epoch [2/15], Step [330/500], Loss: 1.9656, Accuracy: 25.00%,Validation Accuracy: 35.20%
# Epoch [2/15], Step [360/500], Loss: 2.0248, Accuracy: 34.38%,Validation Accuracy: 34.15%
# Epoch [2/15], Step [390/500], Loss: 1.7404, Accuracy: 37.50%,Validation Accuracy: 35.80%
# Epoch [2/15], Step [420/500], Loss: 1.5306, Accuracy: 40.62%,Validation Accuracy: 38.05%
# Epoch [2/15], Step [450/500], Loss: 1.7503, Accuracy: 40.62%,Validation Accuracy: 38.60%
# Epoch [2/15], Step [480/500], Loss: 1.6362, Accuracy: 43.75%,Validation Accuracy: 39.50%
# Epoch [3/15], Step [30/500], Loss: 1.8939, Accuracy: 40.62%,Validation Accuracy: 41.95%
# Epoch [3/15], Step [60/500], Loss: 1.8651, Accuracy: 40.62%,Validation Accuracy: 44.25%
# Epoch [3/15], Step [90/500], Loss: 1.6939, Accuracy: 40.62%,Validation Accuracy: 43.20%
# Epoch [3/15], Step [120/500], Loss: 1.4774, Accuracy: 40.62%,Validation Accuracy: 42.40%
# Epoch [3/15], Step [150/500], Loss: 1.7918, Accuracy: 40.62%,Validation Accuracy: 41.70%
# Epoch [3/15], Step [180/500], Loss: 2.1064, Accuracy: 28.12%,Validation Accuracy: 41.25%
# Epoch [3/15], Step [210/500], Loss: 1.8548, Accuracy: 34.38%,Validation Accuracy: 42.45%
# Epoch [3/15], Step [240/500], Loss: 1.6850, Accuracy: 40.62%,Validation Accuracy: 46.55%
# Epoch [3/15], Step [270/500], Loss: 1.6356, Accuracy: 31.25%,Validation Accuracy: 46.30%
# Epoch [3/15], Step [300/500], Loss: 1.7875, Accuracy: 34.38%,Validation Accuracy: 45.15%
# Epoch [3/15], Step [330/500], Loss: 1.8988, Accuracy: 31.25%,Validation Accuracy: 45.50%
# Epoch [3/15], Step [360/500], Loss: 1.4740, Accuracy: 53.12%,Validation Accuracy: 46.55%
# Epoch [3/15], Step [390/500], Loss: 1.9381, Accuracy: 34.38%,Validation Accuracy: 45.60%
# Epoch [3/15], Step [420/500], Loss: 1.7550, Accuracy: 37.50%,Validation Accuracy: 46.65%
# Epoch [3/15], Step [450/500], Loss: 1.8937, Accuracy: 25.00%,Validation Accuracy: 45.85%
# Epoch [3/15], Step [480/500], Loss: 1.4048, Accuracy: 56.25%,Validation Accuracy: 48.50%
# Epoch [4/15], Step [30/500], Loss: 1.6547, Accuracy: 43.75%,Validation Accuracy: 49.75%
# Epoch [4/15], Step [60/500], Loss: 1.5730, Accuracy: 37.50%,Validation Accuracy: 48.65%
# Epoch [4/15], Step [90/500], Loss: 1.3575, Accuracy: 56.25%,Validation Accuracy: 52.45%
# Epoch [4/15], Step [120/500], Loss: 1.5020, Accuracy: 50.00%,Validation Accuracy: 51.25%
# Epoch [4/15], Step [150/500], Loss: 1.5265, Accuracy: 46.88%,Validation Accuracy: 49.05%
# Epoch [4/15], Step [180/500], Loss: 1.5304, Accuracy: 43.75%,Validation Accuracy: 51.00%
# Epoch [4/15], Step [210/500], Loss: 1.1327, Accuracy: 65.62%,Validation Accuracy: 53.65%
# Epoch [4/15], Step [240/500], Loss: 1.5797, Accuracy: 59.38%,Validation Accuracy: 51.75%
# Epoch [4/15], Step [270/500], Loss: 1.4078, Accuracy: 65.62%,Validation Accuracy: 52.90%
# Epoch [4/15], Step [300/500], Loss: 1.5352, Accuracy: 53.12%,Validation Accuracy: 52.85%
# Epoch [4/15], Step [330/500], Loss: 1.2857, Accuracy: 59.38%,Validation Accuracy: 55.85%
# Epoch [4/15], Step [360/500], Loss: 1.5268, Accuracy: 37.50%,Validation Accuracy: 51.45%
# Epoch [4/15], Step [390/500], Loss: 1.1685, Accuracy: 65.62%,Validation Accuracy: 53.70%
# Epoch [4/15], Step [420/500], Loss: 1.6038, Accuracy: 50.00%,Validation Accuracy: 55.70%
# Epoch [4/15], Step [450/500], Loss: 1.5972, Accuracy: 53.12%,Validation Accuracy: 55.75%
# Epoch [4/15], Step [480/500], Loss: 1.3633, Accuracy: 56.25%,Validation Accuracy: 54.00%
# Epoch [5/15], Step [30/500], Loss: 1.2538, Accuracy: 53.12%,Validation Accuracy: 57.25%
# Epoch [5/15], Step [60/500], Loss: 1.2832, Accuracy: 56.25%,Validation Accuracy: 57.60%
# Epoch [5/15], Step [90/500], Loss: 1.4294, Accuracy: 50.00%,Validation Accuracy: 55.90%
# Epoch [5/15], Step [120/500], Loss: 1.0223, Accuracy: 68.75%,Validation Accuracy: 58.05%
# Epoch [5/15], Step [150/500], Loss: 1.2151, Accuracy: 59.38%,Validation Accuracy: 56.10%
# Epoch [5/15], Step [180/500], Loss: 1.0885, Accuracy: 56.25%,Validation Accuracy: 57.55%
# Epoch [5/15], Step [210/500], Loss: 1.4674, Accuracy: 43.75%,Validation Accuracy: 58.25%
# Epoch [5/15], Step [240/500], Loss: 1.3848, Accuracy: 56.25%,Validation Accuracy: 59.50%
# Epoch [5/15], Step [270/500], Loss: 1.2919, Accuracy: 59.38%,Validation Accuracy: 58.90%
# Epoch [5/15], Step [300/500], Loss: 1.2399, Accuracy: 56.25%,Validation Accuracy: 57.40%
# Epoch [5/15], Step [330/500], Loss: 1.2253, Accuracy: 56.25%,Validation Accuracy: 55.85%
# Epoch [5/15], Step [360/500], Loss: 1.1442, Accuracy: 62.50%,Validation Accuracy: 55.60%
# Epoch [5/15], Step [390/500], Loss: 1.4318, Accuracy: 50.00%,Validation Accuracy: 58.05%
# Epoch [5/15], Step [420/500], Loss: 1.1467, Accuracy: 62.50%,Validation Accuracy: 62.10%
# Epoch [5/15], Step [450/500], Loss: 1.2811, Accuracy: 53.12%,Validation Accuracy: 61.15%
# Epoch [5/15], Step [480/500], Loss: 1.2555, Accuracy: 53.12%,Validation Accuracy: 60.30%
# Epoch [6/15], Step [30/500], Loss: 0.9894, Accuracy: 62.50%,Validation Accuracy: 61.50%
# Epoch [6/15], Step [60/500], Loss: 1.1789, Accuracy: 56.25%,Validation Accuracy: 60.35%
# Epoch [6/15], Step [90/500], Loss: 0.7617, Accuracy: 75.00%,Validation Accuracy: 60.60%
# Epoch [6/15], Step [120/500], Loss: 1.2273, Accuracy: 68.75%,Validation Accuracy: 63.90%
# Epoch [6/15], Step [150/500], Loss: 0.8608, Accuracy: 75.00%,Validation Accuracy: 62.20%
# Epoch [6/15], Step [180/500], Loss: 1.1246, Accuracy: 59.38%,Validation Accuracy: 61.60%
# Epoch [6/15], Step [210/500], Loss: 0.9995, Accuracy: 59.38%,Validation Accuracy: 61.65%
# Epoch [6/15], Step [240/500], Loss: 1.1393, Accuracy: 62.50%,Validation Accuracy: 61.10%
# Epoch [6/15], Step [270/500], Loss: 1.3789, Accuracy: 56.25%,Validation Accuracy: 61.20%
# Epoch [6/15], Step [300/500], Loss: 1.0233, Accuracy: 75.00%,Validation Accuracy: 61.00%
# Epoch [6/15], Step [330/500], Loss: 1.1575, Accuracy: 62.50%,Validation Accuracy: 63.25%
# Epoch [6/15], Step [360/500], Loss: 0.9435, Accuracy: 68.75%,Validation Accuracy: 62.95%
# Epoch [6/15], Step [390/500], Loss: 1.1897, Accuracy: 56.25%,Validation Accuracy: 62.45%
# Epoch [6/15], Step [420/500], Loss: 1.0642, Accuracy: 71.88%,Validation Accuracy: 62.80%
# Epoch [6/15], Step [450/500], Loss: 1.1174, Accuracy: 65.62%,Validation Accuracy: 65.55%
# Epoch [6/15], Step [480/500], Loss: 1.1860, Accuracy: 56.25%,Validation Accuracy: 64.00%
# Epoch [7/15], Step [30/500], Loss: 1.2125, Accuracy: 59.38%,Validation Accuracy: 62.65%
# Epoch [7/15], Step [60/500], Loss: 1.2293, Accuracy: 59.38%,Validation Accuracy: 66.00%
# Epoch [7/15], Step [90/500], Loss: 1.1288, Accuracy: 62.50%,Validation Accuracy: 65.55%
# Epoch [7/15], Step [120/500], Loss: 0.8916, Accuracy: 71.88%,Validation Accuracy: 65.50%
# Epoch [7/15], Step [150/500], Loss: 1.0276, Accuracy: 75.00%,Validation Accuracy: 66.00%
# Epoch [7/15], Step [180/500], Loss: 1.2509, Accuracy: 65.62%,Validation Accuracy: 63.60%
# Epoch [7/15], Step [210/500], Loss: 1.2105, Accuracy: 59.38%,Validation Accuracy: 62.90%
# Epoch [7/15], Step [240/500], Loss: 1.1551, Accuracy: 62.50%,Validation Accuracy: 64.80%
# Epoch [7/15], Step [270/500], Loss: 1.1354, Accuracy: 62.50%,Validation Accuracy: 65.90%
# Epoch [7/15], Step [300/500], Loss: 0.9010, Accuracy: 68.75%,Validation Accuracy: 65.65%
# Epoch [7/15], Step [330/500], Loss: 0.9527, Accuracy: 65.62%,Validation Accuracy: 64.60%
# Epoch [7/15], Step [360/500], Loss: 1.2292, Accuracy: 59.38%,Validation Accuracy: 65.70%
# Epoch [7/15], Step [390/500], Loss: 1.2946, Accuracy: 56.25%,Validation Accuracy: 65.85%
# Epoch [7/15], Step [420/500], Loss: 1.7513, Accuracy: 50.00%,Validation Accuracy: 64.30%
# Epoch [7/15], Step [450/500], Loss: 1.2157, Accuracy: 65.62%,Validation Accuracy: 64.55%
# Epoch [7/15], Step [480/500], Loss: 1.0402, Accuracy: 68.75%,Validation Accuracy: 67.70%
# Epoch [8/15], Step [30/500], Loss: 1.4020, Accuracy: 43.75%,Validation Accuracy: 66.05%
# Epoch [8/15], Step [60/500], Loss: 0.7521, Accuracy: 84.38%,Validation Accuracy: 65.70%
# Epoch [8/15], Step [90/500], Loss: 0.9144, Accuracy: 68.75%,Validation Accuracy: 67.30%
# Epoch [8/15], Step [120/500], Loss: 1.3044, Accuracy: 62.50%,Validation Accuracy: 68.00%
# Epoch [8/15], Step [150/500], Loss: 1.0936, Accuracy: 53.12%,Validation Accuracy: 67.70%
# Epoch [8/15], Step [180/500], Loss: 0.8071, Accuracy: 71.88%,Validation Accuracy: 66.00%
# Epoch [8/15], Step [210/500], Loss: 0.8002, Accuracy: 75.00%,Validation Accuracy: 68.20%
# Epoch [8/15], Step [240/500], Loss: 0.9900, Accuracy: 65.62%,Validation Accuracy: 68.20%
# Epoch [8/15], Step [270/500], Loss: 0.7984, Accuracy: 75.00%,Validation Accuracy: 64.00%
# Epoch [8/15], Step [300/500], Loss: 0.8015, Accuracy: 68.75%,Validation Accuracy: 68.35%
# Epoch [8/15], Step [330/500], Loss: 0.7834, Accuracy: 81.25%,Validation Accuracy: 66.40%
# Epoch [8/15], Step [360/500], Loss: 1.1959, Accuracy: 56.25%,Validation Accuracy: 68.95%
# Epoch [8/15], Step [390/500], Loss: 1.2606, Accuracy: 68.75%,Validation Accuracy: 67.55%
# Epoch [8/15], Step [420/500], Loss: 1.1366, Accuracy: 59.38%,Validation Accuracy: 69.30%
# Epoch [8/15], Step [450/500], Loss: 1.0379, Accuracy: 62.50%,Validation Accuracy: 69.35%
# Epoch [8/15], Step [480/500], Loss: 0.8561, Accuracy: 71.88%,Validation Accuracy: 70.45%
# Epoch [9/15], Step [30/500], Loss: 0.8730, Accuracy: 65.62%,Validation Accuracy: 69.00%
# Epoch [9/15], Step [60/500], Loss: 0.9966, Accuracy: 62.50%,Validation Accuracy: 69.25%
# Epoch [9/15], Step [90/500], Loss: 1.0503, Accuracy: 56.25%,Validation Accuracy: 68.30%
# Epoch [9/15], Step [120/500], Loss: 0.6949, Accuracy: 84.38%,Validation Accuracy: 68.20%
# Epoch [9/15], Step [150/500], Loss: 0.9522, Accuracy: 65.62%,Validation Accuracy: 68.60%
# Epoch [9/15], Step [180/500], Loss: 0.7895, Accuracy: 71.88%,Validation Accuracy: 68.70%
# Epoch [9/15], Step [210/500], Loss: 0.3476, Accuracy: 90.62%,Validation Accuracy: 71.10%
# Epoch [9/15], Step [240/500], Loss: 0.7529, Accuracy: 78.12%,Validation Accuracy: 69.90%
# Epoch [9/15], Step [270/500], Loss: 0.5597, Accuracy: 84.38%,Validation Accuracy: 67.85%
# Epoch [9/15], Step [300/500], Loss: 1.2200, Accuracy: 65.62%,Validation Accuracy: 69.10%
# Epoch [9/15], Step [330/500], Loss: 1.0024, Accuracy: 59.38%,Validation Accuracy: 70.55%
# Epoch [9/15], Step [360/500], Loss: 0.5847, Accuracy: 78.12%,Validation Accuracy: 70.25%
# Epoch [9/15], Step [390/500], Loss: 0.6982, Accuracy: 78.12%,Validation Accuracy: 67.30%
# Epoch [9/15], Step [420/500], Loss: 0.8531, Accuracy: 75.00%,Validation Accuracy: 68.35%
# Epoch [9/15], Step [450/500], Loss: 0.8693, Accuracy: 71.88%,Validation Accuracy: 69.15%
# Epoch [9/15], Step [480/500], Loss: 1.1773, Accuracy: 65.62%,Validation Accuracy: 66.20%
# Epoch [10/15], Step [30/500], Loss: 0.8261, Accuracy: 71.88%,Validation Accuracy: 70.05%
# Epoch [10/15], Step [60/500], Loss: 0.7587, Accuracy: 75.00%,Validation Accuracy: 68.80%
# Epoch [10/15], Step [90/500], Loss: 0.9726, Accuracy: 68.75%,Validation Accuracy: 69.90%
# Epoch [10/15], Step [120/500], Loss: 0.8329, Accuracy: 71.88%,Validation Accuracy: 69.35%
# Epoch [10/15], Step [150/500], Loss: 0.8716, Accuracy: 75.00%,Validation Accuracy: 70.40%
# Epoch [10/15], Step [180/500], Loss: 0.8779, Accuracy: 71.88%,Validation Accuracy: 68.60%
# Epoch [10/15], Step [210/500], Loss: 1.0857, Accuracy: 59.38%,Validation Accuracy: 70.30%
# Epoch [10/15], Step [240/500], Loss: 0.7733, Accuracy: 75.00%,Validation Accuracy: 71.45%
# Epoch [10/15], Step [270/500], Loss: 1.1791, Accuracy: 68.75%,Validation Accuracy: 71.25%
# Epoch [10/15], Step [300/500], Loss: 0.8279, Accuracy: 71.88%,Validation Accuracy: 71.60%
# Epoch [10/15], Step [330/500], Loss: 0.8891, Accuracy: 68.75%,Validation Accuracy: 70.30%
# Epoch [10/15], Step [360/500], Loss: 0.3986, Accuracy: 84.38%,Validation Accuracy: 71.70%
# Epoch [10/15], Step [390/500], Loss: 0.9409, Accuracy: 68.75%,Validation Accuracy: 68.40%
# Epoch [10/15], Step [420/500], Loss: 0.8803, Accuracy: 71.88%,Validation Accuracy: 70.85%
# Epoch [10/15], Step [450/500], Loss: 0.7251, Accuracy: 78.12%,Validation Accuracy: 70.85%
# Epoch [10/15], Step [480/500], Loss: 0.5338, Accuracy: 81.25%,Validation Accuracy: 70.40%
# Epoch [11/15], Step [30/500], Loss: 1.0432, Accuracy: 62.50%,Validation Accuracy: 70.95%
# Epoch [11/15], Step [60/500], Loss: 0.7521, Accuracy: 75.00%,Validation Accuracy: 70.15%
# Epoch [11/15], Step [90/500], Loss: 0.5713, Accuracy: 84.38%,Validation Accuracy: 70.90%
# Epoch [11/15], Step [120/500], Loss: 0.7928, Accuracy: 68.75%,Validation Accuracy: 70.20%
# Epoch [11/15], Step [150/500], Loss: 0.7709, Accuracy: 68.75%,Validation Accuracy: 71.55%
# Epoch [11/15], Step [180/500], Loss: 0.6944, Accuracy: 81.25%,Validation Accuracy: 72.25%
# Epoch [11/15], Step [210/500], Loss: 0.5691, Accuracy: 78.12%,Validation Accuracy: 71.95%
# Epoch [11/15], Step [240/500], Loss: 0.9225, Accuracy: 65.62%,Validation Accuracy: 72.10%
# Epoch [11/15], Step [270/500], Loss: 0.6650, Accuracy: 75.00%,Validation Accuracy: 70.80%
# Epoch [11/15], Step [300/500], Loss: 0.5951, Accuracy: 81.25%,Validation Accuracy: 70.55%
# Epoch [11/15], Step [330/500], Loss: 0.5357, Accuracy: 81.25%,Validation Accuracy: 69.80%
# Epoch [11/15], Step [360/500], Loss: 0.6446, Accuracy: 78.12%,Validation Accuracy: 73.25%
# Epoch [11/15], Step [390/500], Loss: 0.7671, Accuracy: 81.25%,Validation Accuracy: 72.10%
# Epoch [11/15], Step [420/500], Loss: 0.7187, Accuracy: 81.25%,Validation Accuracy: 70.05%
# Epoch [11/15], Step [450/500], Loss: 0.9548, Accuracy: 65.62%,Validation Accuracy: 72.20%
# Epoch [11/15], Step [480/500], Loss: 1.1167, Accuracy: 68.75%,Validation Accuracy: 71.90%
# Epoch [12/15], Step [30/500], Loss: 0.3825, Accuracy: 90.62%,Validation Accuracy: 71.00%
# Epoch [12/15], Step [60/500], Loss: 0.8453, Accuracy: 84.38%,Validation Accuracy: 72.60%
# Epoch [12/15], Step [90/500], Loss: 0.6878, Accuracy: 78.12%,Validation Accuracy: 71.50%
# Epoch [12/15], Step [120/500], Loss: 0.7649, Accuracy: 75.00%,Validation Accuracy: 72.20%
# Epoch [12/15], Step [150/500], Loss: 0.7036, Accuracy: 75.00%,Validation Accuracy: 74.15%
# Epoch [12/15], Step [180/500], Loss: 1.1336, Accuracy: 68.75%,Validation Accuracy: 73.20%
# Epoch [12/15], Step [210/500], Loss: 0.6837, Accuracy: 75.00%,Validation Accuracy: 71.95%
# Epoch [12/15], Step [240/500], Loss: 0.8256, Accuracy: 78.12%,Validation Accuracy: 71.35%
# Epoch [12/15], Step [270/500], Loss: 0.9169, Accuracy: 68.75%,Validation Accuracy: 74.60%
# Epoch [12/15], Step [300/500], Loss: 0.6879, Accuracy: 81.25%,Validation Accuracy: 73.20%
# Epoch [12/15], Step [330/500], Loss: 0.6395, Accuracy: 81.25%,Validation Accuracy: 73.70%
# Epoch [12/15], Step [360/500], Loss: 1.0031, Accuracy: 65.62%,Validation Accuracy: 71.15%
# Epoch [12/15], Step [390/500], Loss: 0.8906, Accuracy: 68.75%,Validation Accuracy: 73.80%
# Epoch [12/15], Step [420/500], Loss: 0.9431, Accuracy: 75.00%,Validation Accuracy: 72.40%
# Epoch [12/15], Step [450/500], Loss: 0.5486, Accuracy: 81.25%,Validation Accuracy: 72.40%
# Epoch [12/15], Step [480/500], Loss: 0.4526, Accuracy: 87.50%,Validation Accuracy: 74.75%
# Epoch [13/15], Step [30/500], Loss: 0.2554, Accuracy: 90.62%,Validation Accuracy: 73.55%
# Epoch [13/15], Step [60/500], Loss: 0.5018, Accuracy: 87.50%,Validation Accuracy: 74.80%
# Epoch [13/15], Step [90/500], Loss: 0.8149, Accuracy: 81.25%,Validation Accuracy: 72.60%
# Epoch [13/15], Step [120/500], Loss: 0.6675, Accuracy: 81.25%,Validation Accuracy: 73.05%
# Epoch [13/15], Step [150/500], Loss: 0.4843, Accuracy: 84.38%,Validation Accuracy: 72.55%
# Epoch [13/15], Step [180/500], Loss: 0.6647, Accuracy: 81.25%,Validation Accuracy: 74.20%
# Epoch [13/15], Step [210/500], Loss: 0.7443, Accuracy: 78.12%,Validation Accuracy: 71.60%
# Epoch [13/15], Step [240/500], Loss: 0.6784, Accuracy: 78.12%,Validation Accuracy: 71.00%
# Epoch [13/15], Step [270/500], Loss: 0.5989, Accuracy: 81.25%,Validation Accuracy: 72.20%
# Epoch [13/15], Step [300/500], Loss: 0.7196, Accuracy: 75.00%,Validation Accuracy: 73.75%
# Epoch [13/15], Step [330/500], Loss: 0.6741, Accuracy: 78.12%,Validation Accuracy: 72.80%
# Epoch [13/15], Step [360/500], Loss: 0.7705, Accuracy: 75.00%,Validation Accuracy: 74.55%
# Epoch [13/15], Step [390/500], Loss: 1.0208, Accuracy: 59.38%,Validation Accuracy: 73.35%
# Epoch [13/15], Step [420/500], Loss: 0.5625, Accuracy: 84.38%,Validation Accuracy: 70.70%
# Epoch [13/15], Step [450/500], Loss: 1.1103, Accuracy: 68.75%,Validation Accuracy: 72.75%
# Epoch [13/15], Step [480/500], Loss: 0.5803, Accuracy: 81.25%,Validation Accuracy: 72.55%
# Epoch [14/15], Step [30/500], Loss: 0.6186, Accuracy: 84.38%,Validation Accuracy: 72.95%
# Epoch [14/15], Step [60/500], Loss: 0.6861, Accuracy: 75.00%,Validation Accuracy: 73.25%
# Epoch [14/15], Step [90/500], Loss: 0.4586, Accuracy: 81.25%,Validation Accuracy: 71.70%
# Epoch [14/15], Step [120/500], Loss: 0.6119, Accuracy: 75.00%,Validation Accuracy: 72.20%
# Epoch [14/15], Step [150/500], Loss: 0.3934, Accuracy: 87.50%,Validation Accuracy: 73.25%
# Epoch [14/15], Step [180/500], Loss: 0.8125, Accuracy: 71.88%,Validation Accuracy: 71.90%
# Epoch [14/15], Step [210/500], Loss: 0.3572, Accuracy: 90.62%,Validation Accuracy: 72.95%
# Epoch [14/15], Step [240/500], Loss: 0.5615, Accuracy: 84.38%,Validation Accuracy: 74.70%
# Epoch [14/15], Step [270/500], Loss: 0.9988, Accuracy: 62.50%,Validation Accuracy: 72.30%
# Epoch [14/15], Step [300/500], Loss: 0.8005, Accuracy: 75.00%,Validation Accuracy: 73.80%
# Epoch [14/15], Step [330/500], Loss: 0.2727, Accuracy: 87.50%,Validation Accuracy: 73.65%
# Epoch [14/15], Step [360/500], Loss: 0.7090, Accuracy: 75.00%,Validation Accuracy: 74.50%
# Epoch [14/15], Step [390/500], Loss: 0.6428, Accuracy: 84.38%,Validation Accuracy: 73.70%
# Epoch [14/15], Step [420/500], Loss: 0.4277, Accuracy: 84.38%,Validation Accuracy: 75.35%
# Epoch [14/15], Step [450/500], Loss: 0.7313, Accuracy: 81.25%,Validation Accuracy: 75.30%
# Epoch [14/15], Step [480/500], Loss: 0.5993, Accuracy: 75.00%,Validation Accuracy: 73.55%
# Epoch [15/15], Step [30/500], Loss: 0.5365, Accuracy: 87.50%,Validation Accuracy: 74.10%
# Epoch [15/15], Step [60/500], Loss: 0.4378, Accuracy: 87.50%,Validation Accuracy: 72.85%
# Epoch [15/15], Step [90/500], Loss: 0.4582, Accuracy: 87.50%,Validation Accuracy: 71.85%
# Epoch [15/15], Step [120/500], Loss: 0.4527, Accuracy: 84.38%,Validation Accuracy: 74.40%
# Epoch [15/15], Step [150/500], Loss: 0.5061, Accuracy: 84.38%,Validation Accuracy: 73.60%
# Epoch [15/15], Step [180/500], Loss: 0.6385, Accuracy: 78.12%,Validation Accuracy: 75.60%
# Epoch [15/15], Step [210/500], Loss: 0.5634, Accuracy: 84.38%,Validation Accuracy: 71.40%
# Epoch [15/15], Step [240/500], Loss: 0.5436, Accuracy: 84.38%,Validation Accuracy: 73.10%
# Epoch [15/15], Step [270/500], Loss: 0.5523, Accuracy: 81.25%,Validation Accuracy: 73.90%
# Epoch [15/15], Step [300/500], Loss: 0.4497, Accuracy: 87.50%,Validation Accuracy: 72.65%
# Epoch [15/15], Step [330/500], Loss: 0.5312, Accuracy: 75.00%,Validation Accuracy: 75.05%
# Epoch [15/15], Step [360/500], Loss: 0.3582, Accuracy: 93.75%,Validation Accuracy: 76.25%
# Epoch [15/15], Step [390/500], Loss: 0.5869, Accuracy: 78.12%,Validation Accuracy: 74.80%
# Epoch [15/15], Step [420/500], Loss: 0.6563, Accuracy: 78.12%,Validation Accuracy: 74.40%
# Epoch [15/15], Step [450/500], Loss: 1.0975, Accuracy: 65.62%,Validation Accuracy: 73.95%
# Epoch [15/15], Step [480/500], Loss: 0.5001, Accuracy: 84.38%,Validation Accuracy: 76.15%
# ######## Training Finished in 8856.872306346893 seconds ###########
# ######## Training timer per epoch is 590.4581537564595 seconds ###########
# Test Accuracy of the model on the 2000 test images: 72.1 %
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78       198
#            1       0.76      0.79      0.77       192
#            2       0.87      0.68      0.76       210
#            3       0.78      0.84      0.81       190
#            4       0.83      0.68      0.74       219
#            5       0.73      0.67      0.70       185
#            6       0.96      0.64      0.77       184
#            7       0.73      0.64      0.68       201
#            8       0.47      0.79      0.59       198
#            9       0.66      0.69      0.67       223
#
#     accuracy                           0.72      2000
#    macro avg       0.75      0.72      0.73      2000
# weighted avg       0.75      0.72      0.73      2000
# Learning Rate: 0.0005, Batch Size: 32 , Loss function:  Cross Entropy Loss , Optimizer:  Adam Optimizer
# Device: cuda
# Epoch [1/15], Step [30/500], Loss: 2.2992, Accuracy: 18.75%,Validation Accuracy: 10.05%
# Epoch [1/15], Step [60/500], Loss: 2.3011, Accuracy: 18.75%,Validation Accuracy: 8.70%
# Epoch [1/15], Step [90/500], Loss: 2.3032, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [1/15], Step [120/500], Loss: 2.3012, Accuracy: 6.25%,Validation Accuracy: 8.70%
# Epoch [1/15], Step [150/500], Loss: 2.3045, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [1/15], Step [180/500], Loss: 2.3098, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [1/15], Step [210/500], Loss: 2.3058, Accuracy: 12.50%,Validation Accuracy: 8.70%
# Epoch [1/15], Step [240/500], Loss: 2.3014, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [1/15], Step [270/500], Loss: 2.3040, Accuracy: 12.50%,Validation Accuracy: 8.70%
# Epoch [1/15], Step [300/500], Loss: 2.3121, Accuracy: 6.25%,Validation Accuracy: 8.55%
# Epoch [1/15], Step [330/500], Loss: 2.3047, Accuracy: 15.62%,Validation Accuracy: 8.55%
# Epoch [1/15], Step [360/500], Loss: 2.3056, Accuracy: 0.00%,Validation Accuracy: 9.65%
# Epoch [1/15], Step [390/500], Loss: 2.3022, Accuracy: 15.62%,Validation Accuracy: 9.10%
# Epoch [1/15], Step [420/500], Loss: 2.3004, Accuracy: 25.00%,Validation Accuracy: 8.90%
# Epoch [1/15], Step [450/500], Loss: 2.3028, Accuracy: 3.12%,Validation Accuracy: 9.45%
# Epoch [1/15], Step [480/500], Loss: 2.3032, Accuracy: 6.25%,Validation Accuracy: 10.05%
# Epoch [2/15], Step [30/500], Loss: 2.2987, Accuracy: 15.62%,Validation Accuracy: 9.10%
# Epoch [2/15], Step [60/500], Loss: 2.3092, Accuracy: 0.00%,Validation Accuracy: 9.90%
# Epoch [2/15], Step [90/500], Loss: 2.3029, Accuracy: 9.38%,Validation Accuracy: 10.10%
# Epoch [2/15], Step [120/500], Loss: 2.3023, Accuracy: 21.88%,Validation Accuracy: 10.50%
# Epoch [2/15], Step [150/500], Loss: 2.3064, Accuracy: 3.12%,Validation Accuracy: 9.95%
# Epoch [2/15], Step [180/500], Loss: 2.3001, Accuracy: 15.62%,Validation Accuracy: 10.05%
# Epoch [2/15], Step [210/500], Loss: 2.2969, Accuracy: 12.50%,Validation Accuracy: 9.70%
# Epoch [2/15], Step [240/500], Loss: 2.3068, Accuracy: 9.38%,Validation Accuracy: 9.90%
# Epoch [2/15], Step [270/500], Loss: 2.2972, Accuracy: 25.00%,Validation Accuracy: 8.75%
# Epoch [2/15], Step [300/500], Loss: 2.3037, Accuracy: 9.38%,Validation Accuracy: 9.30%
# Epoch [2/15], Step [330/500], Loss: 2.3036, Accuracy: 3.12%,Validation Accuracy: 8.55%
# Epoch [2/15], Step [360/500], Loss: 2.3012, Accuracy: 9.38%,Validation Accuracy: 8.65%
# Epoch [2/15], Step [390/500], Loss: 2.3052, Accuracy: 9.38%,Validation Accuracy: 8.40%
# Epoch [2/15], Step [420/500], Loss: 2.3022, Accuracy: 12.50%,Validation Accuracy: 9.85%
# Epoch [2/15], Step [450/500], Loss: 2.3032, Accuracy: 12.50%,Validation Accuracy: 9.25%
# Epoch [2/15], Step [480/500], Loss: 2.3008, Accuracy: 6.25%,Validation Accuracy: 9.20%
# Epoch [3/15], Step [30/500], Loss: 2.3021, Accuracy: 12.50%,Validation Accuracy: 9.10%
# Epoch [3/15], Step [60/500], Loss: 2.3018, Accuracy: 6.25%,Validation Accuracy: 9.00%
# Epoch [3/15], Step [90/500], Loss: 2.3023, Accuracy: 15.62%,Validation Accuracy: 9.35%
# Epoch [3/15], Step [120/500], Loss: 2.3041, Accuracy: 12.50%,Validation Accuracy: 9.90%
# Epoch [3/15], Step [150/500], Loss: 2.3077, Accuracy: 6.25%,Validation Accuracy: 10.15%
# Epoch [3/15], Step [180/500], Loss: 2.3052, Accuracy: 6.25%,Validation Accuracy: 8.35%
# Epoch [3/15], Step [210/500], Loss: 2.3004, Accuracy: 18.75%,Validation Accuracy: 8.90%
# Epoch [3/15], Step [240/500], Loss: 2.3048, Accuracy: 9.38%,Validation Accuracy: 8.45%
# Epoch [3/15], Step [270/500], Loss: 2.3013, Accuracy: 3.12%,Validation Accuracy: 8.85%
# Epoch [3/15], Step [300/500], Loss: 2.3007, Accuracy: 6.25%,Validation Accuracy: 9.15%
# Epoch [3/15], Step [330/500], Loss: 2.3014, Accuracy: 15.62%,Validation Accuracy: 9.15%
# Epoch [3/15], Step [360/500], Loss: 2.3062, Accuracy: 3.12%,Validation Accuracy: 9.00%
# Epoch [3/15], Step [390/500], Loss: 2.3030, Accuracy: 15.62%,Validation Accuracy: 8.30%
# Epoch [3/15], Step [420/500], Loss: 2.3051, Accuracy: 6.25%,Validation Accuracy: 8.75%
# Epoch [3/15], Step [450/500], Loss: 2.3015, Accuracy: 9.38%,Validation Accuracy: 8.75%
# Epoch [3/15], Step [480/500], Loss: 2.3002, Accuracy: 15.62%,Validation Accuracy: 8.80%
# Epoch [4/15], Step [30/500], Loss: 2.2986, Accuracy: 15.62%,Validation Accuracy: 8.50%
# Epoch [4/15], Step [60/500], Loss: 2.2994, Accuracy: 12.50%,Validation Accuracy: 8.00%
# Epoch [4/15], Step [90/500], Loss: 2.3038, Accuracy: 9.38%,Validation Accuracy: 8.30%
# Epoch [4/15], Step [120/500], Loss: 2.2989, Accuracy: 12.50%,Validation Accuracy: 8.35%
# Epoch [4/15], Step [150/500], Loss: 2.3004, Accuracy: 12.50%,Validation Accuracy: 9.25%
# Epoch [4/15], Step [180/500], Loss: 2.3033, Accuracy: 12.50%,Validation Accuracy: 8.80%
# Epoch [4/15], Step [210/500], Loss: 2.2982, Accuracy: 9.38%,Validation Accuracy: 8.55%
# Epoch [4/15], Step [240/500], Loss: 2.2976, Accuracy: 25.00%,Validation Accuracy: 8.55%
# Epoch [4/15], Step [270/500], Loss: 2.3084, Accuracy: 6.25%,Validation Accuracy: 8.55%
# Epoch [4/15], Step [300/500], Loss: 2.2979, Accuracy: 12.50%,Validation Accuracy: 8.45%
# Epoch [4/15], Step [330/500], Loss: 2.3050, Accuracy: 3.12%,Validation Accuracy: 8.75%
# Epoch [4/15], Step [360/500], Loss: 2.3076, Accuracy: 9.38%,Validation Accuracy: 9.75%
# Epoch [4/15], Step [390/500], Loss: 2.3045, Accuracy: 6.25%,Validation Accuracy: 9.15%
# Epoch [4/15], Step [420/500], Loss: 2.2989, Accuracy: 6.25%,Validation Accuracy: 8.45%
# Epoch [4/15], Step [450/500], Loss: 2.3006, Accuracy: 18.75%,Validation Accuracy: 7.60%
# Epoch [4/15], Step [480/500], Loss: 2.3031, Accuracy: 6.25%,Validation Accuracy: 8.70%
# Epoch [5/15], Step [30/500], Loss: 2.3033, Accuracy: 3.12%,Validation Accuracy: 8.10%
# Epoch [5/15], Step [60/500], Loss: 2.2999, Accuracy: 12.50%,Validation Accuracy: 8.50%
# Epoch [5/15], Step [90/500], Loss: 2.3077, Accuracy: 3.12%,Validation Accuracy: 8.65%
# Epoch [5/15], Step [120/500], Loss: 2.3026, Accuracy: 9.38%,Validation Accuracy: 8.65%
# Epoch [5/15], Step [150/500], Loss: 2.3054, Accuracy: 3.12%,Validation Accuracy: 8.60%
# Epoch [5/15], Step [180/500], Loss: 2.3022, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [5/15], Step [210/500], Loss: 2.3017, Accuracy: 9.38%,Validation Accuracy: 8.55%
# Epoch [5/15], Step [240/500], Loss: 2.3043, Accuracy: 12.50%,Validation Accuracy: 8.70%
# Epoch [5/15], Step [270/500], Loss: 2.3034, Accuracy: 6.25%,Validation Accuracy: 8.55%
# Epoch [5/15], Step [300/500], Loss: 2.3021, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [5/15], Step [330/500], Loss: 2.3025, Accuracy: 9.38%,Validation Accuracy: 8.65%
# Epoch [5/15], Step [360/500], Loss: 2.3040, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [5/15], Step [390/500], Loss: 2.2993, Accuracy: 25.00%,Validation Accuracy: 8.70%
# Epoch [5/15], Step [420/500], Loss: 2.3047, Accuracy: 3.12%,Validation Accuracy: 8.70%
# Epoch [5/15], Step [450/500], Loss: 2.2999, Accuracy: 15.62%,Validation Accuracy: 8.70%
# Epoch [5/15], Step [480/500], Loss: 2.3036, Accuracy: 6.25%,Validation Accuracy: 8.95%
# Epoch [6/15], Step [30/500], Loss: 2.3026, Accuracy: 15.62%,Validation Accuracy: 9.50%
# Epoch [6/15], Step [60/500], Loss: 2.2988, Accuracy: 12.50%,Validation Accuracy: 9.00%
# Epoch [6/15], Step [90/500], Loss: 2.3069, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [6/15], Step [120/500], Loss: 2.3032, Accuracy: 15.62%,Validation Accuracy: 8.70%
# Epoch [6/15], Step [150/500], Loss: 2.3058, Accuracy: 6.25%,Validation Accuracy: 8.70%
# Epoch [6/15], Step [180/500], Loss: 2.2994, Accuracy: 12.50%,Validation Accuracy: 8.70%
# Epoch [6/15], Step [210/500], Loss: 2.3045, Accuracy: 6.25%,Validation Accuracy: 8.70%
# Epoch [6/15], Step [240/500], Loss: 2.2984, Accuracy: 25.00%,Validation Accuracy: 8.70%
# Epoch [6/15], Step [270/500], Loss: 2.2986, Accuracy: 15.62%,Validation Accuracy: 8.75%
# Epoch [6/15], Step [300/500], Loss: 2.3085, Accuracy: 3.12%,Validation Accuracy: 8.75%
# Epoch [6/15], Step [330/500], Loss: 2.3022, Accuracy: 15.62%,Validation Accuracy: 8.70%
# Epoch [6/15], Step [360/500], Loss: 2.2984, Accuracy: 15.62%,Validation Accuracy: 8.70%
# Epoch [6/15], Step [390/500], Loss: 2.2999, Accuracy: 18.75%,Validation Accuracy: 8.65%
# Epoch [6/15], Step [420/500], Loss: 2.3028, Accuracy: 6.25%,Validation Accuracy: 8.70%
# Epoch [6/15], Step [450/500], Loss: 2.3013, Accuracy: 9.38%,Validation Accuracy: 9.35%
# Epoch [6/15], Step [480/500], Loss: 2.3027, Accuracy: 6.25%,Validation Accuracy: 8.55%
# Epoch [7/15], Step [30/500], Loss: 2.3004, Accuracy: 9.38%,Validation Accuracy: 9.45%
# Epoch [7/15], Step [60/500], Loss: 2.2993, Accuracy: 15.62%,Validation Accuracy: 9.20%
# Epoch [7/15], Step [90/500], Loss: 2.3015, Accuracy: 15.62%,Validation Accuracy: 8.65%
# Epoch [7/15], Step [120/500], Loss: 2.3028, Accuracy: 6.25%,Validation Accuracy: 8.75%
# Epoch [7/15], Step [150/500], Loss: 2.2996, Accuracy: 15.62%,Validation Accuracy: 8.50%
# Epoch [7/15], Step [180/500], Loss: 2.3048, Accuracy: 9.38%,Validation Accuracy: 8.60%
# Epoch [7/15], Step [210/500], Loss: 2.3063, Accuracy: 6.25%,Validation Accuracy: 8.10%
# Epoch [7/15], Step [240/500], Loss: 2.3034, Accuracy: 9.38%,Validation Accuracy: 8.25%
# Epoch [7/15], Step [270/500], Loss: 2.3019, Accuracy: 9.38%,Validation Accuracy: 9.00%
# Epoch [7/15], Step [300/500], Loss: 2.3016, Accuracy: 15.62%,Validation Accuracy: 8.95%
# Epoch [7/15], Step [330/500], Loss: 2.3046, Accuracy: 6.25%,Validation Accuracy: 8.70%
# Epoch [7/15], Step [360/500], Loss: 2.3014, Accuracy: 9.38%,Validation Accuracy: 9.05%
# Epoch [7/15], Step [390/500], Loss: 2.3016, Accuracy: 9.38%,Validation Accuracy: 9.25%
# Epoch [7/15], Step [420/500], Loss: 2.3032, Accuracy: 3.12%,Validation Accuracy: 7.95%
# Epoch [7/15], Step [450/500], Loss: 2.3009, Accuracy: 12.50%,Validation Accuracy: 8.60%
# Epoch [7/15], Step [480/500], Loss: 2.3022, Accuracy: 9.38%,Validation Accuracy: 8.80%
# Epoch [8/15], Step [30/500], Loss: 2.3026, Accuracy: 12.50%,Validation Accuracy: 8.45%
# Epoch [8/15], Step [60/500], Loss: 2.3047, Accuracy: 12.50%,Validation Accuracy: 8.00%
# Epoch [8/15], Step [90/500], Loss: 2.3004, Accuracy: 18.75%,Validation Accuracy: 8.95%
# Epoch [8/15], Step [120/500], Loss: 2.3015, Accuracy: 9.38%,Validation Accuracy: 9.40%
# Epoch [8/15], Step [150/500], Loss: 2.3036, Accuracy: 9.38%,Validation Accuracy: 8.95%
# Epoch [8/15], Step [180/500], Loss: 2.3042, Accuracy: 3.12%,Validation Accuracy: 9.20%
# Epoch [8/15], Step [210/500], Loss: 2.3083, Accuracy: 3.12%,Validation Accuracy: 8.85%
# Epoch [8/15], Step [240/500], Loss: 2.3010, Accuracy: 15.62%,Validation Accuracy: 8.90%
# Epoch [8/15], Step [270/500], Loss: 2.3035, Accuracy: 12.50%,Validation Accuracy: 9.85%
# Epoch [8/15], Step [300/500], Loss: 2.3055, Accuracy: 9.38%,Validation Accuracy: 9.45%
# Epoch [8/15], Step [330/500], Loss: 2.3002, Accuracy: 9.38%,Validation Accuracy: 9.20%
# Epoch [8/15], Step [360/500], Loss: 2.2998, Accuracy: 12.50%,Validation Accuracy: 9.20%
# Epoch [8/15], Step [390/500], Loss: 2.3025, Accuracy: 12.50%,Validation Accuracy: 9.75%
# Epoch [8/15], Step [420/500], Loss: 2.3035, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [8/15], Step [450/500], Loss: 2.3008, Accuracy: 12.50%,Validation Accuracy: 8.30%
# Epoch [8/15], Step [480/500], Loss: 2.3050, Accuracy: 6.25%,Validation Accuracy: 9.35%
# Epoch [9/15], Step [30/500], Loss: 2.3050, Accuracy: 6.25%,Validation Accuracy: 8.40%
# Epoch [9/15], Step [60/500], Loss: 2.3008, Accuracy: 12.50%,Validation Accuracy: 10.15%
# Epoch [9/15], Step [90/500], Loss: 2.2991, Accuracy: 18.75%,Validation Accuracy: 10.35%
# Epoch [9/15], Step [120/500], Loss: 2.3064, Accuracy: 3.12%,Validation Accuracy: 10.15%
# Epoch [9/15], Step [150/500], Loss: 2.3028, Accuracy: 12.50%,Validation Accuracy: 10.30%
# Epoch [9/15], Step [180/500], Loss: 2.3070, Accuracy: 9.38%,Validation Accuracy: 10.30%
# Epoch [9/15], Step [210/500], Loss: 2.3023, Accuracy: 9.38%,Validation Accuracy: 10.20%
# Epoch [9/15], Step [240/500], Loss: 2.3061, Accuracy: 6.25%,Validation Accuracy: 10.00%
# Epoch [9/15], Step [270/500], Loss: 2.3060, Accuracy: 3.12%,Validation Accuracy: 10.05%
# Epoch [9/15], Step [300/500], Loss: 2.3018, Accuracy: 9.38%,Validation Accuracy: 8.60%
# Epoch [9/15], Step [330/500], Loss: 2.2991, Accuracy: 15.62%,Validation Accuracy: 8.70%
# Epoch [9/15], Step [360/500], Loss: 2.3045, Accuracy: 9.38%,Validation Accuracy: 8.10%
# Epoch [9/15], Step [390/500], Loss: 2.2990, Accuracy: 21.88%,Validation Accuracy: 8.20%
# Epoch [9/15], Step [420/500], Loss: 2.3043, Accuracy: 9.38%,Validation Accuracy: 9.30%
# Epoch [9/15], Step [450/500], Loss: 2.2980, Accuracy: 21.88%,Validation Accuracy: 8.30%
# Epoch [9/15], Step [480/500], Loss: 2.2990, Accuracy: 15.62%,Validation Accuracy: 8.45%
# Epoch [10/15], Step [30/500], Loss: 2.2998, Accuracy: 12.50%,Validation Accuracy: 9.25%
# Epoch [10/15], Step [60/500], Loss: 2.3040, Accuracy: 12.50%,Validation Accuracy: 8.40%
# Epoch [10/15], Step [90/500], Loss: 2.2982, Accuracy: 18.75%,Validation Accuracy: 8.25%
# Epoch [10/15], Step [120/500], Loss: 2.2984, Accuracy: 18.75%,Validation Accuracy: 8.60%
# Epoch [10/15], Step [150/500], Loss: 2.2985, Accuracy: 12.50%,Validation Accuracy: 8.55%
# Epoch [10/15], Step [180/500], Loss: 2.3039, Accuracy: 6.25%,Validation Accuracy: 8.75%
# Epoch [10/15], Step [210/500], Loss: 2.3010, Accuracy: 6.25%,Validation Accuracy: 9.65%
# Epoch [10/15], Step [240/500], Loss: 2.3043, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [10/15], Step [270/500], Loss: 2.3055, Accuracy: 12.50%,Validation Accuracy: 9.30%
# Epoch [10/15], Step [300/500], Loss: 2.3003, Accuracy: 18.75%,Validation Accuracy: 8.65%
# Epoch [10/15], Step [330/500], Loss: 2.3031, Accuracy: 9.38%,Validation Accuracy: 8.20%
# Epoch [10/15], Step [360/500], Loss: 2.3034, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [10/15], Step [390/500], Loss: 2.3075, Accuracy: 6.25%,Validation Accuracy: 9.05%
# Epoch [10/15], Step [420/500], Loss: 2.3052, Accuracy: 0.00%,Validation Accuracy: 8.90%
# Epoch [10/15], Step [450/500], Loss: 2.3009, Accuracy: 12.50%,Validation Accuracy: 8.60%
# Epoch [10/15], Step [480/500], Loss: 2.3040, Accuracy: 9.38%,Validation Accuracy: 8.45%
# Epoch [11/15], Step [30/500], Loss: 2.3037, Accuracy: 15.62%,Validation Accuracy: 8.70%
# Epoch [11/15], Step [60/500], Loss: 2.3027, Accuracy: 12.50%,Validation Accuracy: 8.75%
# Epoch [11/15], Step [90/500], Loss: 2.3014, Accuracy: 15.62%,Validation Accuracy: 8.90%
# Epoch [11/15], Step [120/500], Loss: 2.3030, Accuracy: 15.62%,Validation Accuracy: 8.60%
# Epoch [11/15], Step [150/500], Loss: 2.2980, Accuracy: 25.00%,Validation Accuracy: 8.50%
# Epoch [11/15], Step [180/500], Loss: 2.3034, Accuracy: 12.50%,Validation Accuracy: 8.55%
# Epoch [11/15], Step [210/500], Loss: 2.2978, Accuracy: 15.62%,Validation Accuracy: 8.55%
# Epoch [11/15], Step [240/500], Loss: 2.3024, Accuracy: 12.50%,Validation Accuracy: 8.55%
# Epoch [11/15], Step [270/500], Loss: 2.3018, Accuracy: 3.12%,Validation Accuracy: 8.55%
# Epoch [11/15], Step [300/500], Loss: 2.2998, Accuracy: 15.62%,Validation Accuracy: 8.45%
# Epoch [11/15], Step [330/500], Loss: 2.2997, Accuracy: 18.75%,Validation Accuracy: 8.55%
# Epoch [11/15], Step [360/500], Loss: 2.3014, Accuracy: 9.38%,Validation Accuracy: 8.55%
# Epoch [11/15], Step [390/500], Loss: 2.3023, Accuracy: 6.25%,Validation Accuracy: 8.50%
# Epoch [11/15], Step [420/500], Loss: 2.3007, Accuracy: 6.25%,Validation Accuracy: 9.20%
# Epoch [11/15], Step [450/500], Loss: 2.3043, Accuracy: 6.25%,Validation Accuracy: 7.75%
# Epoch [11/15], Step [480/500], Loss: 2.3006, Accuracy: 9.38%,Validation Accuracy: 8.80%
# Epoch [12/15], Step [30/500], Loss: 2.3022, Accuracy: 18.75%,Validation Accuracy: 8.70%
# Epoch [12/15], Step [60/500], Loss: 2.3016, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [12/15], Step [90/500], Loss: 2.3060, Accuracy: 0.00%,Validation Accuracy: 8.35%
# Epoch [12/15], Step [120/500], Loss: 2.2994, Accuracy: 18.75%,Validation Accuracy: 9.05%
# Epoch [12/15], Step [150/500], Loss: 2.2993, Accuracy: 15.62%,Validation Accuracy: 9.45%
# Epoch [12/15], Step [180/500], Loss: 2.2991, Accuracy: 6.25%,Validation Accuracy: 8.80%
# Epoch [12/15], Step [210/500], Loss: 2.3008, Accuracy: 12.50%,Validation Accuracy: 8.45%
# Epoch [12/15], Step [240/500], Loss: 2.3063, Accuracy: 3.12%,Validation Accuracy: 8.10%
# Epoch [12/15], Step [270/500], Loss: 2.3018, Accuracy: 12.50%,Validation Accuracy: 8.30%
# Epoch [12/15], Step [300/500], Loss: 2.3054, Accuracy: 9.38%,Validation Accuracy: 9.70%
# Epoch [12/15], Step [330/500], Loss: 2.3011, Accuracy: 12.50%,Validation Accuracy: 8.70%
# Epoch [12/15], Step [360/500], Loss: 2.3050, Accuracy: 3.12%,Validation Accuracy: 8.70%
# Epoch [12/15], Step [390/500], Loss: 2.3036, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [12/15], Step [420/500], Loss: 2.3031, Accuracy: 15.62%,Validation Accuracy: 8.70%
# Epoch [12/15], Step [450/500], Loss: 2.2984, Accuracy: 15.62%,Validation Accuracy: 9.05%
# Epoch [12/15], Step [480/500], Loss: 2.3020, Accuracy: 3.12%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [30/500], Loss: 2.3026, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [60/500], Loss: 2.3001, Accuracy: 12.50%,Validation Accuracy: 8.60%
# Epoch [13/15], Step [90/500], Loss: 2.3025, Accuracy: 3.12%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [120/500], Loss: 2.3019, Accuracy: 12.50%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [150/500], Loss: 2.3031, Accuracy: 15.62%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [180/500], Loss: 2.3039, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [210/500], Loss: 2.3026, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [240/500], Loss: 2.3051, Accuracy: 6.25%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [270/500], Loss: 2.3032, Accuracy: 6.25%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [300/500], Loss: 2.3057, Accuracy: 12.50%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [330/500], Loss: 2.2986, Accuracy: 15.62%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [360/500], Loss: 2.3002, Accuracy: 6.25%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [390/500], Loss: 2.3020, Accuracy: 15.62%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [420/500], Loss: 2.3024, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [13/15], Step [450/500], Loss: 2.3041, Accuracy: 6.25%,Validation Accuracy: 9.05%
# Epoch [13/15], Step [480/500], Loss: 2.3014, Accuracy: 3.12%,Validation Accuracy: 8.20%
# Epoch [14/15], Step [30/500], Loss: 2.3024, Accuracy: 6.25%,Validation Accuracy: 9.45%
# Epoch [14/15], Step [60/500], Loss: 2.3031, Accuracy: 15.62%,Validation Accuracy: 8.15%
# Epoch [14/15], Step [90/500], Loss: 2.2993, Accuracy: 9.38%,Validation Accuracy: 8.60%
# Epoch [14/15], Step [120/500], Loss: 2.3002, Accuracy: 12.50%,Validation Accuracy: 8.20%
# Epoch [14/15], Step [150/500], Loss: 2.2979, Accuracy: 25.00%,Validation Accuracy: 8.75%
# Epoch [14/15], Step [180/500], Loss: 2.3040, Accuracy: 12.50%,Validation Accuracy: 8.70%
# Epoch [14/15], Step [210/500], Loss: 2.3035, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [14/15], Step [240/500], Loss: 2.3021, Accuracy: 18.75%,Validation Accuracy: 8.75%
# Epoch [14/15], Step [270/500], Loss: 2.3000, Accuracy: 18.75%,Validation Accuracy: 8.70%
# Epoch [14/15], Step [300/500], Loss: 2.3065, Accuracy: 3.12%,Validation Accuracy: 8.70%
# Epoch [14/15], Step [330/500], Loss: 2.3012, Accuracy: 15.62%,Validation Accuracy: 8.70%
# Epoch [14/15], Step [360/500], Loss: 2.3044, Accuracy: 3.12%,Validation Accuracy: 8.70%
# Epoch [14/15], Step [390/500], Loss: 2.3023, Accuracy: 12.50%,Validation Accuracy: 8.70%
# Epoch [14/15], Step [420/500], Loss: 2.3011, Accuracy: 25.00%,Validation Accuracy: 8.70%
# Epoch [14/15], Step [450/500], Loss: 2.3049, Accuracy: 0.00%,Validation Accuracy: 8.70%
# Epoch [14/15], Step [480/500], Loss: 2.3039, Accuracy: 9.38%,Validation Accuracy: 9.65%
# Epoch [15/15], Step [30/500], Loss: 2.3021, Accuracy: 6.25%,Validation Accuracy: 8.70%
# Epoch [15/15], Step [60/500], Loss: 2.3020, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [15/15], Step [90/500], Loss: 2.3006, Accuracy: 9.38%,Validation Accuracy: 8.70%
# Epoch [15/15], Step [120/500], Loss: 2.2992, Accuracy: 28.12%,Validation Accuracy: 8.70%
# Epoch [15/15], Step [150/500], Loss: 2.3053, Accuracy: 3.12%,Validation Accuracy: 8.70%
# Epoch [15/15], Step [180/500], Loss: 2.3014, Accuracy: 28.12%,Validation Accuracy: 8.70%
# Epoch [15/15], Step [210/500], Loss: 2.3017, Accuracy: 6.25%,Validation Accuracy: 8.70%
# Epoch [15/15], Step [240/500], Loss: 2.3016, Accuracy: 6.25%,Validation Accuracy: 8.70%
# Epoch [15/15], Step [270/500], Loss: 2.2987, Accuracy: 18.75%,Validation Accuracy: 8.70%
# Epoch [15/15], Step [300/500], Loss: 2.3018, Accuracy: 6.25%,Validation Accuracy: 8.70%
# Epoch [15/15], Step [330/500], Loss: 2.3003, Accuracy: 18.75%,Validation Accuracy: 9.35%
# Epoch [15/15], Step [360/500], Loss: 2.3023, Accuracy: 12.50%,Validation Accuracy: 8.35%
# Epoch [15/15], Step [390/500], Loss: 2.3027, Accuracy: 12.50%,Validation Accuracy: 9.20%
# Epoch [15/15], Step [420/500], Loss: 2.3021, Accuracy: 15.62%,Validation Accuracy: 8.55%
# Epoch [15/15], Step [450/500], Loss: 2.2998, Accuracy: 15.62%,Validation Accuracy: 9.15%
# Epoch [15/15], Step [480/500], Loss: 2.3008, Accuracy: 6.25%,Validation Accuracy: 8.35%
# ######## Training Finished in 8794.050255537033 seconds ###########
# ######## Training timer per epoch is 586.2700170358022 seconds ###########
# Test Accuracy of the model on the 2000 test images: 9.9 %
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       212
#            1       0.10      1.00      0.18       198
#            2       0.00      0.00      0.00       187
#            3       0.00      0.00      0.00       212
#            4       0.00      0.00      0.00       197
#            5       0.00      0.00      0.00       191
#            6       0.00      0.00      0.00       211
#            7       0.00      0.00      0.00       214
#            8       0.00      0.00      0.00       191
#            9       0.00      0.00      0.00       187
#
#     accuracy                           0.10      2000
#    macro avg       0.01      0.10      0.02      2000
# weighted avg       0.01      0.10      0.02      2000
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Learning Rate: 0.001, Batch Size: 32 , Loss function:  Cross Entropy Loss , Optimizer:  Adam Optimizer
# Device: cuda
# Epoch [1/15], Step [30/500], Loss: 2.3029, Accuracy: 9.38%,Validation Accuracy: 9.85%
# Epoch [1/15], Step [60/500], Loss: 2.2989, Accuracy: 12.50%,Validation Accuracy: 9.10%
# Epoch [1/15], Step [90/500], Loss: 2.3018, Accuracy: 15.62%,Validation Accuracy: 9.85%
# Epoch [1/15], Step [120/500], Loss: 2.3009, Accuracy: 6.25%,Validation Accuracy: 9.80%
# Epoch [1/15], Step [150/500], Loss: 2.3083, Accuracy: 12.50%,Validation Accuracy: 9.85%
# Epoch [1/15], Step [180/500], Loss: 2.3029, Accuracy: 12.50%,Validation Accuracy: 10.10%
# Epoch [1/15], Step [210/500], Loss: 2.2975, Accuracy: 12.50%,Validation Accuracy: 11.70%
# Epoch [1/15], Step [240/500], Loss: 2.3046, Accuracy: 12.50%,Validation Accuracy: 10.40%
# Epoch [1/15], Step [270/500], Loss: 2.3057, Accuracy: 3.12%,Validation Accuracy: 10.30%
# Epoch [1/15], Step [300/500], Loss: 2.3045, Accuracy: 18.75%,Validation Accuracy: 9.20%
# Epoch [1/15], Step [330/500], Loss: 2.3055, Accuracy: 3.12%,Validation Accuracy: 8.85%
# Epoch [1/15], Step [360/500], Loss: 2.3008, Accuracy: 15.62%,Validation Accuracy: 9.20%
# Epoch [1/15], Step [390/500], Loss: 2.3014, Accuracy: 15.62%,Validation Accuracy: 8.85%
# Epoch [1/15], Step [420/500], Loss: 2.3041, Accuracy: 0.00%,Validation Accuracy: 9.70%
# Epoch [1/15], Step [450/500], Loss: 2.2990, Accuracy: 18.75%,Validation Accuracy: 9.40%
# Epoch [1/15], Step [480/500], Loss: 2.3004, Accuracy: 12.50%,Validation Accuracy: 9.10%
# Epoch [2/15], Step [30/500], Loss: 2.3013, Accuracy: 9.38%,Validation Accuracy: 9.25%
# Epoch [2/15], Step [60/500], Loss: 2.3073, Accuracy: 6.25%,Validation Accuracy: 9.85%
# Epoch [2/15], Step [90/500], Loss: 2.3070, Accuracy: 9.38%,Validation Accuracy: 9.75%
# Epoch [2/15], Step [120/500], Loss: 2.3027, Accuracy: 3.12%,Validation Accuracy: 9.80%
# Epoch [2/15], Step [150/500], Loss: 2.3046, Accuracy: 6.25%,Validation Accuracy: 9.35%
# Epoch [2/15], Step [180/500], Loss: 2.3015, Accuracy: 18.75%,Validation Accuracy: 9.70%
# Epoch [2/15], Step [210/500], Loss: 2.3047, Accuracy: 6.25%,Validation Accuracy: 9.85%
# Epoch [2/15], Step [240/500], Loss: 2.3060, Accuracy: 15.62%,Validation Accuracy: 8.95%
# Epoch [2/15], Step [270/500], Loss: 2.3099, Accuracy: 3.12%,Validation Accuracy: 9.90%
# Epoch [2/15], Step [300/500], Loss: 2.3042, Accuracy: 15.62%,Validation Accuracy: 9.90%
# ...
# Epoch [6/15], Step [60/500], Loss: 2.3003, Accuracy: 6.25%,Validation Accuracy: 10.20%
# Epoch [6/15], Step [90/500], Loss: 2.2986, Accuracy: 0.00%,Validation Accuracy: 8.85%
# Epoch [6/15], Step [120/500], Loss: 2.3019, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [6/15], Step [150/500], Loss: 2.3151, Accuracy: 3.12%,Validation Accuracy: 10.20%
# Epoch [6/15], Step [180/500], Loss: 2.2990, Accuracy: 21.88%,Validation Accuracy: 8.85%
# Epoch [6/15], Step [210/500], Loss: 2.3158, Accuracy: 6.25%,Validation Accuracy: 9.70%
# Epoch [6/15], Step [240/500], Loss: 2.3145, Accuracy: 9.38%,Validation Accuracy: 8.80%
# Epoch [6/15], Step [270/500], Loss: 2.3020, Accuracy: 6.25%,Validation Accuracy: 10.30%
# Epoch [6/15], Step [300/500], Loss: 2.3001, Accuracy: 9.38%,Validation Accuracy: 8.40%
# Epoch [6/15], Step [330/500], Loss: 2.3182, Accuracy: 0.00%,Validation Accuracy: 9.85%
# Epoch [6/15], Step [360/500], Loss: 2.3064, Accuracy: 9.38%,Validation Accuracy: 10.75%
# Epoch [6/15], Step [390/500], Loss: 2.3019, Accuracy: 6.25%,Validation Accuracy: 10.00%
# Epoch [6/15], Step [420/500], Loss: 2.3047, Accuracy: 15.62%,Validation Accuracy: 8.85%
# Epoch [6/15], Step [450/500], Loss: 2.3011, Accuracy: 18.75%,Validation Accuracy: 9.15%
# Epoch [6/15], Step [480/500], Loss: 2.3086, Accuracy: 15.62%,Validation Accuracy: 9.60%
# Epoch [7/15], Step [30/500], Loss: 2.3121, Accuracy: 6.25%,Validation Accuracy: 9.55%
# Epoch [7/15], Step [60/500], Loss: 2.2986, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [7/15], Step [90/500], Loss: 2.3084, Accuracy: 0.00%,Validation Accuracy: 9.30%
# Epoch [7/15], Step [120/500], Loss: 2.3018, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [7/15], Step [150/500], Loss: 2.3109, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [7/15], Step [180/500], Loss: 2.2977, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [7/15], Step [210/500], Loss: 2.3004, Accuracy: 3.12%,Validation Accuracy: 10.40%
# Epoch [7/15], Step [240/500], Loss: 2.3095, Accuracy: 3.12%,Validation Accuracy: 8.85%
# Epoch [7/15], Step [270/500], Loss: 2.3036, Accuracy: 6.25%,Validation Accuracy: 10.00%
# Epoch [7/15], Step [300/500], Loss: 2.3078, Accuracy: 6.25%,Validation Accuracy: 10.55%
# Epoch [7/15], Step [330/500], Loss: 2.2904, Accuracy: 15.62%,Validation Accuracy: 10.25%
# Epoch [7/15], Step [360/500], Loss: 2.2955, Accuracy: 12.50%,Validation Accuracy: 10.70%
# Epoch [7/15], Step [390/500], Loss: 2.2910, Accuracy: 12.50%,Validation Accuracy: 10.55%
# Epoch [7/15], Step [420/500], Loss: 2.3040, Accuracy: 3.12%,Validation Accuracy: 10.20%
# Epoch [7/15], Step [450/500], Loss: 2.2964, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [7/15], Step [480/500], Loss: 2.3002, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [8/15], Step [30/500], Loss: 2.3052, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [8/15], Step [60/500], Loss: 2.3047, Accuracy: 12.50%,Validation Accuracy: 10.40%
# Epoch [8/15], Step [90/500], Loss: 2.2980, Accuracy: 12.50%,Validation Accuracy: 8.85%
# Epoch [8/15], Step [120/500], Loss: 2.3120, Accuracy: 6.25%,Validation Accuracy: 10.70%
# Epoch [8/15], Step [150/500], Loss: 2.3009, Accuracy: 6.25%,Validation Accuracy: 10.20%
# Epoch [8/15], Step [180/500], Loss: 2.3015, Accuracy: 9.38%,Validation Accuracy: 10.00%
# Epoch [8/15], Step [210/500], Loss: 2.2984, Accuracy: 3.12%,Validation Accuracy: 10.55%
# Epoch [8/15], Step [240/500], Loss: 2.3039, Accuracy: 18.75%,Validation Accuracy: 8.85%
# Epoch [8/15], Step [270/500], Loss: 2.3091, Accuracy: 15.62%,Validation Accuracy: 10.20%
# Epoch [8/15], Step [300/500], Loss: 2.3083, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [8/15], Step [330/500], Loss: 2.3096, Accuracy: 3.12%,Validation Accuracy: 9.35%
# Epoch [8/15], Step [360/500], Loss: 2.3072, Accuracy: 15.62%,Validation Accuracy: 10.20%
# Epoch [8/15], Step [390/500], Loss: 2.3083, Accuracy: 6.25%,Validation Accuracy: 10.55%
# Epoch [8/15], Step [420/500], Loss: 2.3060, Accuracy: 3.12%,Validation Accuracy: 8.85%
# Epoch [8/15], Step [450/500], Loss: 2.3036, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [8/15], Step [480/500], Loss: 2.3027, Accuracy: 12.50%,Validation Accuracy: 8.85%
# Epoch [9/15], Step [30/500], Loss: 2.3063, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [9/15], Step [60/500], Loss: 2.3132, Accuracy: 3.12%,Validation Accuracy: 8.85%
# Epoch [9/15], Step [90/500], Loss: 2.2874, Accuracy: 18.75%,Validation Accuracy: 8.85%
# Epoch [9/15], Step [120/500], Loss: 2.3055, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [9/15], Step [150/500], Loss: 2.2998, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [9/15], Step [180/500], Loss: 2.2936, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [9/15], Step [210/500], Loss: 2.3099, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [9/15], Step [240/500], Loss: 2.3127, Accuracy: 6.25%,Validation Accuracy: 10.55%
# Epoch [9/15], Step [270/500], Loss: 2.3108, Accuracy: 15.62%,Validation Accuracy: 10.55%
# Epoch [9/15], Step [300/500], Loss: 2.3072, Accuracy: 6.25%,Validation Accuracy: 10.00%
# Epoch [9/15], Step [330/500], Loss: 2.3004, Accuracy: 12.50%,Validation Accuracy: 10.70%
# Epoch [9/15], Step [360/500], Loss: 2.3016, Accuracy: 9.38%,Validation Accuracy: 10.40%
# Epoch [9/15], Step [390/500], Loss: 2.3086, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [9/15], Step [420/500], Loss: 2.3006, Accuracy: 3.12%,Validation Accuracy: 9.35%
# Epoch [9/15], Step [450/500], Loss: 2.2980, Accuracy: 15.62%,Validation Accuracy: 10.20%
# Epoch [9/15], Step [480/500], Loss: 2.3044, Accuracy: 9.38%,Validation Accuracy: 9.35%
# Epoch [10/15], Step [30/500], Loss: 2.3051, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [10/15], Step [60/500], Loss: 2.2939, Accuracy: 18.75%,Validation Accuracy: 10.20%
# Epoch [10/15], Step [90/500], Loss: 2.3041, Accuracy: 21.88%,Validation Accuracy: 10.20%
# Epoch [10/15], Step [120/500], Loss: 2.3018, Accuracy: 12.50%,Validation Accuracy: 10.20%
# Epoch [10/15], Step [150/500], Loss: 2.3064, Accuracy: 6.25%,Validation Accuracy: 10.00%
# Epoch [10/15], Step [180/500], Loss: 2.3027, Accuracy: 12.50%,Validation Accuracy: 10.70%
# Epoch [10/15], Step [210/500], Loss: 2.3188, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [10/15], Step [240/500], Loss: 2.3123, Accuracy: 0.00%,Validation Accuracy: 9.35%
# Epoch [10/15], Step [270/500], Loss: 2.3109, Accuracy: 12.50%,Validation Accuracy: 10.70%
# Epoch [10/15], Step [300/500], Loss: 2.2896, Accuracy: 9.38%,Validation Accuracy: 10.70%
# Epoch [10/15], Step [330/500], Loss: 2.3187, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [10/15], Step [360/500], Loss: 2.3130, Accuracy: 12.50%,Validation Accuracy: 10.70%
# Epoch [10/15], Step [390/500], Loss: 2.3059, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [10/15], Step [420/500], Loss: 2.2958, Accuracy: 15.62%,Validation Accuracy: 8.85%
# Epoch [10/15], Step [450/500], Loss: 2.3033, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [10/15], Step [480/500], Loss: 2.2926, Accuracy: 21.88%,Validation Accuracy: 8.85%
# Epoch [11/15], Step [30/500], Loss: 2.3144, Accuracy: 15.62%,Validation Accuracy: 10.55%
# Epoch [11/15], Step [60/500], Loss: 2.3048, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [11/15], Step [90/500], Loss: 2.2943, Accuracy: 18.75%,Validation Accuracy: 8.85%
# Epoch [11/15], Step [120/500], Loss: 2.2982, Accuracy: 15.62%,Validation Accuracy: 8.85%
# Epoch [11/15], Step [150/500], Loss: 2.3094, Accuracy: 6.25%,Validation Accuracy: 9.35%
# Epoch [11/15], Step [180/500], Loss: 2.3015, Accuracy: 6.25%,Validation Accuracy: 10.55%
# Epoch [11/15], Step [210/500], Loss: 2.3030, Accuracy: 12.50%,Validation Accuracy: 10.00%
# Epoch [11/15], Step [240/500], Loss: 2.3061, Accuracy: 12.50%,Validation Accuracy: 10.00%
# Epoch [11/15], Step [270/500], Loss: 2.3005, Accuracy: 12.50%,Validation Accuracy: 10.55%
# Epoch [11/15], Step [300/500], Loss: 2.2979, Accuracy: 15.62%,Validation Accuracy: 10.55%
# Epoch [11/15], Step [330/500], Loss: 2.2822, Accuracy: 18.75%,Validation Accuracy: 8.85%
# Epoch [11/15], Step [360/500], Loss: 2.3189, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [11/15], Step [390/500], Loss: 2.3014, Accuracy: 9.38%,Validation Accuracy: 9.35%
# Epoch [11/15], Step [420/500], Loss: 2.3061, Accuracy: 3.12%,Validation Accuracy: 9.35%
# Epoch [11/15], Step [450/500], Loss: 2.3055, Accuracy: 0.00%,Validation Accuracy: 9.35%
# Epoch [11/15], Step [480/500], Loss: 2.3012, Accuracy: 6.25%,Validation Accuracy: 10.20%
# Epoch [12/15], Step [30/500], Loss: 2.3107, Accuracy: 12.50%,Validation Accuracy: 8.85%
# Epoch [12/15], Step [60/500], Loss: 2.2879, Accuracy: 9.38%,Validation Accuracy: 9.35%
# Epoch [12/15], Step [90/500], Loss: 2.2981, Accuracy: 6.25%,Validation Accuracy: 10.55%
# Epoch [12/15], Step [120/500], Loss: 2.3003, Accuracy: 9.38%,Validation Accuracy: 10.20%
# Epoch [12/15], Step [150/500], Loss: 2.3010, Accuracy: 18.75%,Validation Accuracy: 10.20%
# Epoch [12/15], Step [180/500], Loss: 2.3006, Accuracy: 9.38%,Validation Accuracy: 10.55%
# Epoch [12/15], Step [210/500], Loss: 2.2955, Accuracy: 18.75%,Validation Accuracy: 8.85%
# Epoch [12/15], Step [240/500], Loss: 2.3045, Accuracy: 9.38%,Validation Accuracy: 10.55%
# Epoch [12/15], Step [270/500], Loss: 2.2985, Accuracy: 0.00%,Validation Accuracy: 8.85%
# Epoch [12/15], Step [300/500], Loss: 2.3042, Accuracy: 12.50%,Validation Accuracy: 10.20%
# Epoch [12/15], Step [330/500], Loss: 2.3130, Accuracy: 6.25%,Validation Accuracy: 10.20%
# Epoch [12/15], Step [360/500], Loss: 2.3002, Accuracy: 3.12%,Validation Accuracy: 10.55%
# Epoch [12/15], Step [390/500], Loss: 2.3023, Accuracy: 12.50%,Validation Accuracy: 10.55%
# Epoch [12/15], Step [420/500], Loss: 2.2990, Accuracy: 12.50%,Validation Accuracy: 8.85%
# Epoch [12/15], Step [450/500], Loss: 2.2911, Accuracy: 12.50%,Validation Accuracy: 8.85%
# Epoch [12/15], Step [480/500], Loss: 2.3024, Accuracy: 18.75%,Validation Accuracy: 8.85%
# Epoch [13/15], Step [30/500], Loss: 2.2969, Accuracy: 25.00%,Validation Accuracy: 10.00%
# Epoch [13/15], Step [60/500], Loss: 2.3078, Accuracy: 12.50%,Validation Accuracy: 9.35%
# Epoch [13/15], Step [90/500], Loss: 2.3092, Accuracy: 6.25%,Validation Accuracy: 9.35%
# Epoch [13/15], Step [120/500], Loss: 2.2908, Accuracy: 21.88%,Validation Accuracy: 9.35%
# Epoch [13/15], Step [150/500], Loss: 2.3046, Accuracy: 12.50%,Validation Accuracy: 9.35%
# Epoch [13/15], Step [180/500], Loss: 2.3128, Accuracy: 3.12%,Validation Accuracy: 10.55%
# Epoch [13/15], Step [210/500], Loss: 2.3053, Accuracy: 6.25%,Validation Accuracy: 10.55%
# Epoch [13/15], Step [240/500], Loss: 2.3033, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [13/15], Step [270/500], Loss: 2.2915, Accuracy: 15.62%,Validation Accuracy: 10.00%
# Epoch [13/15], Step [300/500], Loss: 2.3233, Accuracy: 3.12%,Validation Accuracy: 8.85%
# Epoch [13/15], Step [330/500], Loss: 2.3067, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [13/15], Step [360/500], Loss: 2.3192, Accuracy: 3.12%,Validation Accuracy: 8.85%
# Epoch [13/15], Step [390/500], Loss: 2.3057, Accuracy: 6.25%,Validation Accuracy: 10.55%
# Epoch [13/15], Step [420/500], Loss: 2.3110, Accuracy: 6.25%,Validation Accuracy: 10.55%
# Epoch [13/15], Step [450/500], Loss: 2.2972, Accuracy: 12.50%,Validation Accuracy: 8.85%
# Epoch [13/15], Step [480/500], Loss: 2.3034, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [14/15], Step [30/500], Loss: 2.3055, Accuracy: 12.50%,Validation Accuracy: 8.85%
# Epoch [14/15], Step [60/500], Loss: 2.3049, Accuracy: 12.50%,Validation Accuracy: 8.85%
# Epoch [14/15], Step [90/500], Loss: 2.2968, Accuracy: 6.25%,Validation Accuracy: 10.70%
# Epoch [14/15], Step [120/500], Loss: 2.3132, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [14/15], Step [150/500], Loss: 2.3023, Accuracy: 15.62%,Validation Accuracy: 8.85%
# Epoch [14/15], Step [180/500], Loss: 2.3130, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [14/15], Step [210/500], Loss: 2.3178, Accuracy: 3.12%,Validation Accuracy: 8.85%
# Epoch [14/15], Step [240/500], Loss: 2.3003, Accuracy: 15.62%,Validation Accuracy: 8.85%
# Epoch [14/15], Step [270/500], Loss: 2.2873, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [14/15], Step [300/500], Loss: 2.3021, Accuracy: 9.38%,Validation Accuracy: 10.70%
# Epoch [14/15], Step [330/500], Loss: 2.3038, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [14/15], Step [360/500], Loss: 2.2975, Accuracy: 9.38%,Validation Accuracy: 10.20%
# Epoch [14/15], Step [390/500], Loss: 2.3171, Accuracy: 9.38%,Validation Accuracy: 10.70%
# Epoch [14/15], Step [420/500], Loss: 2.3130, Accuracy: 3.12%,Validation Accuracy: 10.55%
# Epoch [14/15], Step [450/500], Loss: 2.2923, Accuracy: 18.75%,Validation Accuracy: 10.55%
# Epoch [14/15], Step [480/500], Loss: 2.3029, Accuracy: 12.50%,Validation Accuracy: 10.00%
# Epoch [15/15], Step [30/500], Loss: 2.3015, Accuracy: 6.25%,Validation Accuracy: 10.20%
# Epoch [15/15], Step [60/500], Loss: 2.2979, Accuracy: 9.38%,Validation Accuracy: 10.20%
# Epoch [15/15], Step [90/500], Loss: 2.3028, Accuracy: 12.50%,Validation Accuracy: 8.85%
# Epoch [15/15], Step [120/500], Loss: 2.3003, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [15/15], Step [150/500], Loss: 2.3233, Accuracy: 3.12%,Validation Accuracy: 10.40%
# Epoch [15/15], Step [180/500], Loss: 2.2961, Accuracy: 15.62%,Validation Accuracy: 10.40%
# Epoch [15/15], Step [210/500], Loss: 2.3079, Accuracy: 3.12%,Validation Accuracy: 10.40%
# Epoch [15/15], Step [240/500], Loss: 2.2962, Accuracy: 12.50%,Validation Accuracy: 9.35%
# Epoch [15/15], Step [270/500], Loss: 2.3087, Accuracy: 3.12%,Validation Accuracy: 8.85%
# Epoch [15/15], Step [300/500], Loss: 2.2978, Accuracy: 12.50%,Validation Accuracy: 10.55%
# Epoch [15/15], Step [330/500], Loss: 2.3035, Accuracy: 15.62%,Validation Accuracy: 9.35%
# Epoch [15/15], Step [360/500], Loss: 2.2989, Accuracy: 12.50%,Validation Accuracy: 8.85%
# Epoch [15/15], Step [390/500], Loss: 2.3006, Accuracy: 6.25%,Validation Accuracy: 8.85%
# Epoch [15/15], Step [420/500], Loss: 2.3151, Accuracy: 9.38%,Validation Accuracy: 8.85%
# Epoch [15/15], Step [450/500], Loss: 2.3204, Accuracy: 3.12%,Validation Accuracy: 8.85%
# Epoch [15/15], Step [480/500], Loss: 2.3127, Accuracy: 0.00%,Validation Accuracy: 8.85%
# ######## Training Finished in 8520.641699075699 seconds ###########
# ######## Training timer per epoch is 568.0427799383799 seconds ###########
# Test Accuracy of the model on the 2000 test images: 10.35 %
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       181
#            1       0.00      0.00      0.00       206
#            2       0.10      1.00      0.19       207
#            3       0.00      0.00      0.00       199
#            4       0.00      0.00      0.00       207
#            5       0.00      0.00      0.00       202
#            6       0.00      0.00      0.00       203
#            7       0.00      0.00      0.00       183
#            8       0.00      0.00      0.00       206
#            9       0.00      0.00      0.00       206
#
#     accuracy                           0.10      2000
#    macro avg       0.01      0.10      0.02      2000
# weighted avg       0.01      0.10      0.02      2000
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### **Storing the loss,training accuracy,validation accuracy in a file**

# %%
# Saving the lists to a file
with open(saveFilePath, 'wb') as f:
    data = {
        'hyper_parameters': hyper_parameters,
        'train_acc_hyper_paramaters': train_acc_hyper_paramaters,
        'train_acc_valid_hyper_paramaters': train_acc_valid_hyper_paramaters,
        'train_loss_hyper_paramaters': train_loss_hyper_paramaters,
        'train_acc_hyper_paramaters_step': train_acc_hyper_paramaters_step,
        'train_acc_valid_hyper_paramaters_step': train_acc_valid_hyper_paramaters_step,
        'train_loss_hyper_paramaters_step': train_loss_hyper_paramaters_step,
        'test_loss': test_loss,
    }
    pickle.dump(data, f)

# %% [markdown]
# ### **Loading the loss,training accuracy,validation accuracy in a file**

# %%
# Loading the lists from the file
with open(saveFilePath, 'rb') as f:
    data = pickle.load(f)
    hyper_parameters = data['hyper_parameters']
    train_acc_hyper_paramaters = data['train_acc_hyper_paramaters']
    train_acc_valid_hyper_paramaters = data['train_acc_valid_hyper_paramaters']
    train_loss_hyper_paramaters = data['train_loss_hyper_paramaters']
    train_acc_hyper_paramaters_step = data['train_acc_hyper_paramaters_step']
    train_acc_valid_hyper_paramaters_step = data['train_acc_valid_hyper_paramaters_step']
    train_loss_hyper_paramaters_step = data['train_loss_hyper_paramaters_step']
    test_loss=data['test_loss']

# %%
num_epochs = [(i+1) for i in range(epochs)]
plt.rcParams.update({'font.size': 12})

# %% [markdown]
# ### **Accuracy Plot(without smoothening)**

# %%
plt.figure(figsize=(10, 10))
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy plot')


for i in range(len(hyper_parameters)):
    plt.plot(num_epochs,train_acc_hyper_paramaters[i],label=hyper_parameters[i][0])
plt.legend()

# %% [markdown]
# ### **Accuracy Plot(with smoothening)**

# %%
epochs = 15
num_epochs = [(i+1) for i in range(epochs)]
plt.figure(figsize=(10, 10))
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy plot(with smoothening)')

window_size = 3  # choose the window size for smoothing

for i in range(len(hyper_parameters)):
    accuracy = train_acc_hyper_paramaters[i]
    smoothed_accuracy = np.convolve(accuracy, np.ones(window_size)/window_size, mode='valid')
    plt.plot(num_epochs[-len(smoothed_accuracy):], smoothed_accuracy, label=hyper_parameters[i][0])
plt.legend()

# %% [markdown]
# ### **Loss Plot(without smoothening)**

# %%
plt.figure(figsize=(10, 10))
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.title('Loss plot')
plt.ylim(0,3)
print()

for i in range(len(hyper_parameters)):
    #print(train_loss_hyper_paramaters[i])
    plt.plot(train_loss_hyper_paramaters[i],label=hyper_parameters[i][0])
plt.legend()

# %% [markdown]
# ### **Loss Plot(with smoothening)**

# %%
epochs = 15
num_epochs = [(i+1) for i in range(epochs)]
plt.figure(figsize=(10, 10))
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.title('Loss plot(with smoothening)')
plt.ylim(0,3)
window_size = 3  # choose the window size for smoothing

for i in range(len(hyper_parameters)):
    losses = train_loss_hyper_paramaters[i]
    smoothed_losses = np.convolve(losses, np.ones(window_size)/window_size, mode='valid')
    plt.plot(num_epochs[-len(smoothed_losses):], smoothed_losses, label=hyper_parameters[i][0])
    
plt.legend()

# %% [markdown]
# ### **Loss Plot with respect to steps(without smoothening)**

# %%
plt.figure(figsize=(15, 10))
plt.xlabel('step')
plt.ylabel('Loss')
plt.title('Loss plot')
plt.ylim(0,3)

for i in range(len(hyper_parameters)):
    plt.plot(train_loss_hyper_paramaters_step[i],label=hyper_parameters[i][0])
plt.legend()

# %% [markdown]
# ### **Loss Plot with respect to steps(with smoothening)**

# %%
plt.figure(figsize=(15, 10))
plt.xlabel('step')
plt.ylabel('Loss')
plt.title('Loss plot')
plt.ylim(0,3)
window_size = 3

for i in range(len(hyper_parameters)):
    # apply moving average filter to loss values
    smoothed_loss = np.convolve(train_loss_hyper_paramaters_step[i], np.ones(window_size)/window_size, mode='valid')
    plt.plot(smoothed_loss, label=hyper_parameters[i][0])

plt.legend()

# %% [markdown]
# ### **Test Accuracy and Learning Rate(Scatter plot)**

# %%
plt.figure(figsize=(10, 10))
plt.xlabel('Learning Rate')
plt.ylabel('Test Accuracy %')
plt.title('Test Accuracy plot')


for i in range(len(hyper_parameters)):
    #print(test_loss[i][0],test_loss[i][1])
    plt.plot(test_loss[i][1],test_loss[i][0], marker='o', markersize=10,label=hyper_parameters[i][0])
plt.legend()

# %% [markdown]
# ### **Training and Validation Plots with respect to epoch**

# %%
plt.rcParams.update({'font.size': 10})
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(20, 10))
fig.suptitle('Accuracy plots', fontsize=20)

for i in range(len(hyper_parameters)):
    row = i // 2
    col = i % 2
    axs[row, col].plot(num_epochs, train_acc_hyper_paramaters[i], label="Training Accuracy")
    axs[row, col].plot(num_epochs, train_acc_valid_hyper_paramaters[i],label="Validation Accuracy")
    axs[row, col].set_xlabel('epoch')
    axs[row, col].set_ylabel('Accuracy')
    axs[row, col].set_title('Accuracy plot for ' + " ".join(hyper_parameters[i][0]))
    axs[row, col].legend()

# %% [markdown]
# ### **Training and Validation Plots with respect to epoch(with smoothing)**

# %%
num_epochs = [(i+1) for i in range(epochs)]
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(20, 10))
fig.suptitle('Accuracy plots(with smoothening)', fontsize=20)

for i in range(len(hyper_parameters)):
    row = i // 2
    col = i % 2

    # Smooth the training accuracy curve
    train_acc_smooth = savgol_filter(train_acc_hyper_paramaters[i], window_length=11, polyorder=3)
    axs[row, col].plot(num_epochs, train_acc_smooth, label="Training Accuracy")

    # Smooth the validation accuracy curve
    val_acc_smooth = savgol_filter(train_acc_valid_hyper_paramaters[i], window_length=11, polyorder=3)
    axs[row, col].plot(num_epochs, val_acc_smooth, label="Validation Accuracy")

    axs[row, col].set_xlabel('epoch')
    axs[row, col].set_ylabel('Accuracy')
    axs[row, col].set_title('Accuracy plot for ' + " ".join(hyper_parameters[i][0]))
    axs[row, col].legend()

# %% [markdown]
# ### **Training and Validation Plots with respect to steps(without smoothing)**

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(20, 10))
fig.suptitle('Accuracy plots', fontsize=20)

for i in range(len(hyper_parameters)):
    row = i // 2
    col = i % 2
    axs[row, col].plot( train_acc_hyper_paramaters_step[i], label="Training Accuracy")
    axs[row, col].plot(train_acc_valid_hyper_paramaters_step[i],label="Validation Accuracy")
    axs[row, col].set_xlabel('Steps')
    axs[row, col].set_ylabel('Accuracy')
    axs[row, col].set_title('Accuracy plot for ' + " ".join(hyper_parameters[i][0]))
    axs[row, col].legend()

# %% [markdown]
# ### **Training and Validation Plots with respect to steps(with Smoothing)**

# %%
# Define a function to compute the moving average of a list
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# Plot the accuracy graphs
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(20, 10))
fig.suptitle('Accuracy plots(with smoothening)', fontsize=20)

for i in range(len(hyper_parameters)):
    row = i // 2
    col = i % 2
   
    # Compute the moving average of the training and validation accuracy
    train_acc_smooth = moving_average(train_acc_hyper_paramaters_step[i], 5)
    valid_acc_smooth = moving_average(train_acc_valid_hyper_paramaters_step[i], 5)
   
    # Plot the smoothed accuracy curves
    axs[row, col].plot(train_acc_smooth, label="Training Accuracy")
    axs[row, col].plot(valid_acc_smooth, label="Validation Accuracy")
   
    axs[row, col].set_xlabel('Steps')
    axs[row, col].set_ylabel('Accuracy')
    axs[row, col].set_title('Accuracy plot for ' + " ".join(hyper_parameters[i]))
    axs[row, col].legend()

plt.show()

# %% [markdown]
# ### **T-SNE Plot (Learning Rate=0.0001)**

# %%
temporaryModel=MODELS[0]

  
  # Get embeddings for the training data
embeddings = []
labels = []
with torch.no_grad():
    for data in train_loader:
        images, targets = data[0].to(device), data[1].to(device)
        outputs = temporaryModel(images)
        embeddings.append(outputs.cpu().numpy())
        labels.append(targets.cpu().numpy())
embeddings = np.concatenate(embeddings)
labels = np.concatenate(labels)

  # Apply t-SNE for visualization
tsne = TSNE(n_components=2, perplexity=30, random_state=0)
embeddings_tsne = tsne.fit_transform(embeddings)

  # Plot t-SNE embeddings
plt.figure(figsize=(18,8))

for i in range(len(labels_map)):
    plt.scatter(embeddings_tsne[labels==i,0], embeddings_tsne[labels==i,1], label=f'Class {i}')
plt.legend()
plt.title('t-SNE Embeddings for Training Data')
plt.xlabel("t-SNE component 1")
plt.ylabel("t-SNE component 2")
plt.show()

# %% [markdown]
# ### **Saving the Model(Learning Rate=0.0001)**

# %%
i=1
torch.save(MODELS[0], saveModelPath+"COMP6721_VGG11_Dataset10_Model"+str(i)+".pth")

# %% [markdown]
# ### **Model FLOPS**

# %%
TempTransformer = transforms.Compose([
    transforms.Resize((256,256)),
    transforms.RandomRotation(20),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(0.1,0.1,0.1),
    transforms.ToTensor(),
    transforms.Normalize([0.554, 0.450, 0.343],[0.231, 0.241, 0.241]),
    transforms.RandomErasing()
  ])





imageInput = Image.open('/content/dataset-10N/Pizza/Pizza-Test (1).jpeg')
input_data = TempTransformer(imageInput)

input_data=input_data.view(1,3,256,256)
print(input_data.size())
#input = torch.randn(1, 3, 256, 256)
VGG11 = models.vgg11()
flops, params = profile(VGG11, inputs=(input_data, ))
print(f"FLOPS: {flops / 1e9:.2f} billion")
# Out:
# torch.Size([1, 3, 256, 256])
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# FLOPS: 9.90 billion

# %% [markdown]
# ### **Output of various models**

# %%
TempTransformer = transforms.Compose([
    transforms.Resize(inputDimension),
    transforms.RandomRotation(20),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(0.1,0.1,0.1),
    transforms.ToTensor(),
    transforms.Normalize([0.554, 0.450, 0.343],[0.231, 0.241, 0.241]),
    transforms.RandomErasing()
  ])

imageInput = Image.open('/content/dataset-10N/Pizza/Pizza-Test (1).jpeg')
input_data = TempTransformer(imageInput)
input_data = input_data.to(device)
input_data = input_data.unsqueeze(0)
i=0
for tempModelList in MODELS:
  tempModelList.eval()
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  tempModelList.to(device)
  print(" ".join(hyper_parameters[i]))
  with torch.no_grad():
    output = tempModelList(input_data)

  out=output.tolist()[0]
  print(labels_map[out.index(max(out))])
  i=i+1
# Out:
# Learning Rate: 0.0001  Batch Size: 32 Cross Entropy Loss Adam Optimizer
# Pizza
# Learning Rate: 0.0005  Batch Size: 32 Cross Entropy Loss Adam Optimizer
# Burger
# Learning Rate: 0.001  Batch Size: 32 Cross Entropy Loss Adam Optimizer
# Taco
# Learning Rate: 0.01  Batch Size: 32 Cross Entropy Loss Adam Optimizer
# Crispy Chicken
